# %% [markdown]
# <a href="https://colab.research.google.com/github/babi00/ai4biological-pattern/blob/guido-clean/invasive_plants_analysis/NEW_model_grid_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Classificatore specie:
# - input: immagine
# - output label: nativa/non nativa e non invasiva/non nativa e invasiva
# La struttura del modello utilizzato è simile a quella precedentemente implementata:
# le immagini passano attraverso un modello preallenato (BioCLIP o ResNet) da cui vengono estratti gli embedding
# gli embedding allenano un semplice classificatore.
#
# La loss function è stata modificata: ogni classe ha il suo peso (dipendente dalla frequenza della classe).
#
# Durante il training le fasi di estrazione degli embedding e predizione del label sono separate (così che il training sia molto più veloce e leggero). Una volta finito il training viene ricostruito il modello intero, così che il classificatore prenda come input l'immagine (non l'embedding) e restituisca il label (in modo che si possa effettuare successivamente explainability sulle immagini e non solo sugli embedding).
#
# Rispetto al modello di Barbara, estraggo gli embeddings tutti insieme (e non separati per training set e validation set), così da poter effettuare cross validation senza dover ogni volta estrarre gli embeddings.

# %%
#@title Imports and downloads
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.transforms import functional as TF
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split, ConcatDataset
from torchvision import transforms, models
# from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, multilabel_confusion_matrix, confusion_matrix, ConfusionMatrixDisplay, f1_score
# import seaborn as sns
# import requests
# from io import BytesIO
from google.colab import drive
import time
from tqdm import tqdm
# !pip install open_clip_torch
import open_clip
# import random
import math
from collections import Counter
import datetime
import json
import os

torch.manual_seed(42)
np.random.seed(42)

drive.mount('/content/drive')

# Clone the repository and checkout the 'clean-barbara' branch
# !git clone --branch clean-barbara https://github.com/babi00/ai4biological-pattern.git
# %cd ai4biological-pattern

# Enable sparse checkout
# !git sparse-checkout init --cone
# Out:
# Requirement already satisfied: open_clip_torch in /usr/local/lib/python3.11/dist-packages (3.0.0)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (0.21.0+cu124)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (2024.11.6)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (6.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (4.67.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (0.33.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (0.5.3)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.11/dist-packages (from open_clip_torch) (1.0.18)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from timm>=1.0.17->open_clip_torch) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->open_clip_torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0->open_clip_torch) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->open_clip_torch) (0.2.13)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open_clip_torch) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->open_clip_torch) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->open_clip_torch) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0->open_clip_torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->open_clip_torch) (2025.7.14)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# fatal: destination path 'ai4biological-pattern' already exists and is not an empty directory.
# /content/ai4biological-pattern

# %%
#@title Traning log saving function
def save_training_log(model_name, output_dir, train_losses, val_losses, train_accuracies, val_accuracies, classification_report_dict):
    import datetime
    import json
    import os

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_dir = f"/content/drive/MyDrive/Thesis/{output_dir}/logs"
    os.makedirs(log_dir, exist_ok=True)
    log_path = os.path.join(log_dir, "training_log.json")

    # Load existing logs (if any)
    if os.path.exists(log_path):
        with open(log_path, "r") as f:
            all_logs = json.load(f)
    else:
        all_logs = []

    # Prepare this run's data
    this_log = {
        "model_name": model_name,
        "timestamp": timestamp,
        "final_train_loss": train_losses[-1] if train_losses else None,
        "final_val_loss": val_losses[-1] if val_losses else None,
        "final_train_accuracy": train_accuracies[-1] if train_accuracies else None,
        "final_val_accuracy": val_accuracies[-1] if val_accuracies else None,
        "classification_report_last_epoch": classification_report_dict[-1] if isinstance(classification_report_dict, list) else classification_report_dict,
        "train_loss_history": train_losses,
        "val_loss_history": val_losses,
        "train_accuracy_history": train_accuracies,
        "val_accuracy_history": val_accuracies
    }

    all_logs.append(this_log)

    # Save updated list
    with open(log_path, "w") as f:
        json.dump(all_logs, f, indent=4)

    print(f"📝 Appended log to {log_path}")

# %%
#@title Horizontal flip
def hflip(image):
  return TF.hflip(image)

# %%
#@title Original Dataset
class InvasiveSpeciesDataset(Dataset):
    def __init__(self, root_dir, transform=None, get_label_fn=None):
        self.root_dir = root_dir
        self.transform = transform
        self.entries = []
        self.label_map = {
            "Invasive" : 0,
            "Non Invasive" : 1
        }

        taxa_folders = [d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d)) and d != "metadata"]
        for taxon in taxa_folders:
            meta_path = os.path.join(root_dir, "filtered_metadata", f"{taxon}_metadata.csv")
            if not os.path.exists(meta_path):
                continue
            metadata_df = pd.read_csv(meta_path)
            # for idx, row in metadata_df.iterrows():
            #     self.entries.append((taxon, row))  # Just index, don’t open anything
            for idx, row in metadata_df.iterrows():
              if pd.isna(row["filename"]):
                  print(f"⚠️ Missing filename in taxon '{taxon}' at index {idx}")
                  continue
              self.entries.append((taxon, row))

    def __len__(self):
        return len(self.entries)

    def __getitem__(self, idx):
        taxon, row = self.entries[idx]
        filename = str(row["filename"])
        image_path = os.path.join(self.root_dir, taxon, filename)
        image = Image.open(image_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        label = self.label_map.get(row["label"])
        return image, label, idx

# %%
#@title Augmented Dataset (TO BE MODIFIED IF USED)
class AugmentedClass1Dataset(Dataset):
  def __init__(self, original_dataset, transform=None):
    self.original_dataset = original_dataset
    self.transform = transform
    self.entries = [entry for entry in original_dataset.entries if original_dataset.label_map.get(entry[1]["label"]) == 1]
    self.root_dir = original_dataset.root_dir

  def __len__(self):
    return len(self.entries)

  def __getitem__(self, idx):
    taxon, row = self.entries[idx]
    filename = str(row['filename'])
    image_path = os.path.join(self.root_dir, taxon, filename)
    image = Image.open(image_path).convert("RGB")
    if self.transform:
        image = self.transform(image)
    label = 1
    return image, label, idx

# %%
#@title Return the dataloader of all images and not already separated (also class weights are not present)
def get_data_loader(root_dir, batch_size=32, use_bioclip=True, preprocess=None):
    if use_bioclip and preprocess:
        transform = preprocess
    else:
        transform = transforms.Compose([
          transforms.Resize((224, 224)),
          transforms.ToTensor()
        ])

    dataset = InvasiveSpeciesDataset(
        root_dir=root_dir,
        transform=transform,
    )

    loader = DataLoader(dataset, batch_size=32, shuffle=False)

    return loader

# %%
#@title Augmentation functions
def get_augmented_transform_flipping(preprocess=None):

    if preprocess:
        # BioCLIP: use its own preprocessing, plus flipping
        return transforms.Compose([
            transforms.Lambda(lambda img: TF.hflip(img)),
            preprocess
        ])
    else:
        # ResNet or default: manual transform
        return transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.Lambda(lambda img: TF.hflip(img)),
            transforms.ToTensor()
        ])


def get_augmented_transform_jitter(preprocess=None):

    if preprocess:
        # BioCLIP: use its own preprocessing, plus jittering (no hue modification)
        return transforms.Compose([
            transforms.ColorJitter(0.3, 0.3, 0.3),
            preprocess
        ])
    else:
        # ResNet or default: manual transform
        return transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ColorJitter(0.3, 0.3, 0.3),
            transforms.ToTensor()
        ])

# %%
#@title Augmented DataLoader
def get_data_loader_augmented(root_dir, batch_size=32, use_bioclip=True, preprocess=None, augmentation='flipping'):
    if use_bioclip and preprocess:
        original_transform = preprocess
    else:
        original_transform = transforms.Compose([
          transforms.Resize((224, 224)),
          transforms.ToTensor(),
          # transforms.RandomHorizontalFlip(p=1.0)
        ])

    if augmentation=='flipping':
      augmented_transform = get_augmented_transform_flipping(preprocess if use_bioclip else None)
    elif augmentation=='jittering':
      augmented_transform = get_augmented_transform_jitter(preprocess if use_bioclip else None)
    else:
      print("Error in the augmentation!")
      augmented_transform = -1 #this will break after


    original_dataset = InvasiveSpeciesDataset(
        root_dir=root_dir,
        transform=original_transform,
    )

    augmented_dataset = AugmentedClass1Dataset(
        original_dataset=original_dataset,
        transform=augmented_transform,
    )

    augmented_loader = DataLoader(augmented_dataset, batch_size=32, shuffle=False)

    return augmented_loader

# %%
#@title 2.Define the embedding extractor:
#ResNet without the last FC layer
def get_resnet_embeddings_extractor_model():
    #Use a pre-trained ResNet18 model
    model = models.resnet18(weights='IMAGENET1K_V1')

    #Freeze all layers
    for param in model.parameters():
        param.requires_grad = False

    embeddings_extractor= nn.Sequential(*list(model.children())[:-1]) #removes the last FC layer
    print("Model obtained...")

    return embeddings_extractor

#BioCLIP model
def get_bioclip_embeddings_extractor_model(device, bioclip_version=2):
    if bioclip_version==2:
        print("BioCLIP 2!")
        model, _, preprocess = open_clip.create_model_and_transforms('hf-hub:imageomics/bioclip-2')
    else:
        model, _, preprocess = open_clip.create_model_and_transforms('hf-hub:imageomics/bioclip')
    print("Model obtained...")
    model.to(device)
    model.eval()
    return model, preprocess

# %%
#@title 3. Extract embeddings using the embeddings_extractor and return the embeddings tensors
def extract_embeddings(dataloader, embeddings_extractor, device, embeddings_save_path, augmented=False, use_bioclip=True, dataset=None):
    embeddings_extractor.eval()
    all_embeddings = []
    all_labels = []
    all_ids = []
    all_groups = []  # ✅ NEW: store taxa names

    with torch.no_grad():
      for images, labels, obs_id in tqdm(dataloader, desc='Extracting embeddings'):
          images = images.to(device)
          if use_bioclip:
              embeddings = embeddings_extractor.encode_image(images)
              embeddings = embeddings / embeddings.norm(dim=-1, keepdim=True)  # Optional: normalize
          else:
              embeddings = embeddings_extractor(images).view(images.size(0), -1)

          all_embeddings.append(embeddings.cpu())
          all_labels.append(labels)
          all_ids.extend(obs_id)

          # ✅ NEW: reconstruct taxa names directly here
          if dataset is not None:
              for i in obs_id:
                  taxon, _ = dataset.entries[int(i)]
                  all_groups.append(taxon)

    embeddings_tensors = torch.cat(all_embeddings, dim=0).to(device)
    labels_tensors = torch.cat(all_labels, dim=0).to(device)
    obs_id_tensor = torch.tensor(all_ids).to(device)

    all_embeddings = {
       'embeddings' : embeddings_tensors,
       'labels' : labels_tensors,
       'ids' : obs_id_tensor,
       'groups': all_groups  # ✅ Save group names
    }

    if augmented==False:
      torch.save(all_embeddings, embeddings_save_path)

    # embedding_size = embeddings_tensors.shape[1] #useful for classifier

    return all_embeddings

# %%
#@title Split the embeddings 80-20, then add the augmentation to the training set
def split_embeddings(embeddings_dict, augmented_embeddings_dict=None, val_percentage=0.2):

    """Split the embeddings and not the images into training set and validation set"""

    embeddings_tensors = embeddings_dict["embeddings"]
    labels_tensors = embeddings_dict["labels"]
    obs_id_tensor = embeddings_dict["ids"]

    embedding_size = embeddings_tensors.shape[1] #useful for classifier

    dataset = torch.utils.data.TensorDataset(embeddings_tensors, labels_tensors, obs_id_tensor)

    train_size = int((1-val_percentage) * len(dataset))
    val_size = len(dataset) - train_size

    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

    #if using augmentation
    if augmented_embeddings_dict:
      print("Augmenting train dataset...")
      aug_embeddings_tensors = augmented_embeddings_dict["embeddings"]
      aug_labels_tensors = augmented_embeddings_dict["labels"]
      aug_obs_id_tensor = augmented_embeddings_dict["ids"]

      augmented_train_dataset = torch.utils.data.TensorDataset(aug_embeddings_tensors, aug_labels_tensors, aug_obs_id_tensor)

      #concatenate train dataset with augmented train dataset
      train_dataset = ConcatDataset([train_dataset, augmented_train_dataset])

    label_counts = Counter()
    for _, label, _ in train_dataset:
        label_counts[int(label)] += 1

    print("🔢 Class distribution in train set:", label_counts)

    # total = sum(label_counts.values())
    class_weights = torch.tensor([
        1.0 / math.log(1.02 + label_counts[0]),
        1.0 / math.log(1.02 + label_counts[1])
    ], dtype=torch.float)

    print("⚖️ Class weights:", class_weights)

    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=True)

    return train_loader, val_loader, class_weights, embedding_size

# %%
#@title Classifier
class InvasiveSpeciesClassifier(nn.Module):
    def __init__(self, embedding_dim, hidden_dim=256, num_classes=2):
        super().__init__()
        self.classifier = nn.Sequential(
            nn.Linear(embedding_dim, hidden_dim),
            nn.ReLU(), #consider adding a Dropout layer
            # nn.Dropout(0.3), #We remove the dropout layer
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, x):
        return self.classifier(x)

# %%
#@title Early Stopping class

#Patience: how many epochs to wait after last improvements
#delta: minimum change in validation to be considered improvement
class EarlyStopping:

    def __init__(self, patience=5, delta=0.01, verbose=False):
        self.patience = patience
        self.delta = delta
        self.verbose = verbose
        self.best_loss = None
        self.no_improvement_count = 0
        self.stop_training = False

    def check_early_stop(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss - self.delta:
            self.best_loss = val_loss
            self.no_improvement_count = 0
        else:
            self.no_improvement_count += 1
            if self.no_improvement_count >= self.patience:
                self.stop_training = True
                if self.verbose:
                    print("Stopping early as no improvement has been observed.")

# %%
#@title 4. Training function
def train_classifier(train_loader, val_loader, feature_extractor, classifier, optimizer, criterion, device, output_dir, model_name, num_epoch=10, verbose=True, save_classifier=False, do_early_stopping=False):

    train_losses = []
    train_accuracies = []
    val_losses = []
    val_accuracies = []

    early_stopping = EarlyStopping(patience=10, delta=0, verbose=True)

    for epoch in range(num_epoch):
        print(f"\n🔁 Epoch {epoch + 1}/{num_epoch}")
        classifier.train()
        running_loss, correct, total = 0, 0, 0

        for embeddings, labels, _ in tqdm(train_loader, desc="Training"): # Unpack all three values
            outputs = classifier(embeddings)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * embeddings.size(0)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

        train_loss = running_loss / total
        train_acc = correct / total

        val_loss, val_acc, y_true, y_pred = evaluate_classifier(
            val_loader, feature_extractor, classifier, criterion, device
        )

        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)

        if verbose:
            print(f"📉 Train Loss: {train_loss:.4f} | Accuracy: {train_acc:.4f}")
            print(f"📈 Val Loss:   {val_loss:.4f} | Accuracy: {val_acc:.4f}")

            print("\n📋 Classification Report:")
            report_dict = classification_report(y_true, y_pred, labels=[0, 1], target_names=["Invasive", "Non Invasive"], zero_division=0, output_dict=True)
            print(classification_report(y_true, y_pred, labels=[0, 1], target_names=["Invasive", "Non Invasive"], zero_division=0, output_dict=False))

            #plot confusion matrix
            cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
            fig, ax = plt.subplots(figsize=(6, 6))
            im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
            ax.figure.colorbar(im, ax=ax)
            classes = ["Invasive", "Non Invasive"]

            # Show all ticks and label them
            ax.set(xticks=np.arange(len(classes)),
                yticks=np.arange(len(classes)),
                xticklabels=classes,
                yticklabels=classes,
                ylabel='True label',
                xlabel='Predicted label',
                title='Validation Confusion Matrix')

            # Rotate the tick labels and set alignment.
            plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

            # Loop over data dimensions and create text annotations.
            fmt = 'd'
            thresh = cm.max() / 2. if cm.max() > 0 else 1
            for i in range(cm.shape[0]):
                for j in range(cm.shape[1]):
                    ax.text(j, i, format(cm[i, j], fmt),
                            ha="center", va="center",
                            color="white" if cm[i, j] > thresh else "black")

            fig.tight_layout()
            plt.grid(False)
            plt.show()
        else:
          report_dict = None

        if do_early_stopping:
          # Check early stopping condition
          early_stopping.check_early_stop(val_loss)

          if early_stopping.stop_training:
            print(f"Early stopping at epoch {epoch}")
            break


    torch.save(classifier.state_dict(), f'classifier_head_{model_name}.pth')
    google_drive_path = f'/content/drive/MyDrive/Thesis/{output_dir}/classifier_head_{model_name}.pth'
    torch.save(classifier.state_dict(), google_drive_path)

    return train_losses, train_accuracies, val_losses, val_accuracies, report_dict

# %%
#@title 5. Evaluation function
def evaluate_classifier(loader, feature_extractor, classifier, criterion, device):
    classifier.eval()
    total_loss, correct, total = 0, 0, 0

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for embeddings, labels, obs_ids in tqdm(loader, desc="Evaluating"): # Unpack all three values
            embeddings, labels = embeddings.to(device), labels.to(device)
            outputs = classifier(embeddings)
            loss = criterion(outputs, labels)

            total_loss += loss.item() * embeddings.size(0)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / total
    avg_acc = correct / total

    return avg_loss, avg_acc, all_labels, all_preds

# %%
#@title Focal loss function

class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
        """
        alpha: Class weighting (tensor or list), same as in CrossEntropyLoss
        gamma: Focusing parameter (higher → more focus on hard samples) (gamma=0 => cross entropy loss)
        reduction: 'mean', 'sum', or 'none'
        """
        super(FocalLoss, self).__init__()
        self.alpha=alpha
        self.gamma=gamma
        self.reduction=reduction

    def forward(self, inputs, targets):
        #cross entropy per sample (no reduction)
        ce_loss = F.cross_entropy(inputs, targets, weight=self.alpha, reduction='none')

        #convert to probabilities of true class for modulating factor
        pt = torch.exp(-ce_loss) #ce = -log(pt), so pt = e^(-ce), model confidence of true class

        #focal loss formula (focal term)
        focal_loss = ((1-pt)**self.gamma) * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean() #return average loss per batch
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
#@title Full Model
class FullModel(nn.Module):
    def __init__(self, embedding_model, classifier_head):
        super().__init__()
        self.embedding_model = embedding_model
        self.classifier_head = classifier_head

    def forward(self, x):
        with torch.no_grad():
            if hasattr(self.encoder, 'encode_image'):
                features = self.encoder.encode_image(x)
            else:
                features = self.encoder(x)

        if features.ndim == 4:
            features = features.view(features.size(0), -1)

        return self.classifier_head(features)

# %%
#@title Create model and predict
def create_model_and_predict(folder_name="taxas", use_bioclip=True, bioclip_version=None, augmentation=False, augmentation_factor=2,
                             loss_type='CE', output_dir="invasive_species", model_name="prova", verbose=True, save_model=True,
                             embeddings_save_path=None, epochs=50, debug_subset_size=None, do_early_stopping=False):

    start_time = time.time()

    model_name = f'bioclip_2_{model_name}' if use_bioclip and bioclip_version==2 else f'bioclip_1_{model_name}' if use_bioclip else f'resnet_{model_name}'

    github = '/content/ai4biological-pattern/barbara_new'
    github_repository = f'{github}/{folder_name}'

    if not os.path.isdir(github_repository): #check if data has already been downloaded
        # !git sparse-checkout set barbara_new/{folder_name}
        # !git checkout clean-barbara

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    if use_bioclip:
        feature_extractor, preprocess = get_bioclip_embeddings_extractor_model(device, bioclip_version)
        feature_extractor = feature_extractor.to(device)
    else:
        feature_extractor = get_resnet_embeddings_extractor_model()
        feature_extractor = feature_extractor.to(device)
        preprocess = None
    print("Feature extractor obtained..")


    if os.path.exists(embeddings_save_path):

        print("✅ Embeddings already exist, loading from file...")
        embeddings_dict = torch.load(embeddings_save_path)
        # embeddings = embeddings_dict["embeddings"]
        # labels = embeddings_dict["labels"]
        # ids = embeddings_dict["ids"]

        img_loader = get_data_loader(root_dir=github_repository)

        if augmentation:
          #only extract embeddings for augmentated data
          augmented_loader = get_data_loader_augmented(root_dir=github_repository, augmentation='flipping')
          augmented_embeddings_dict = extract_embeddings(augmented_loader, feature_extractor, device, embeddings_save_path=embeddings_save_path, augmented=True, use_bioclip=use_bioclip)

          if augmentation_factor==3:
            augmented_loader_2 = get_data_loader_augmented(root_dir=github_repository, augmentation='jittering')
            augmented_embeddings_dict_2 = extract_embeddings(augmented_loader_2, feature_extractor, device, embeddings_save_path=embeddings_save_path, augmented=True, use_bioclip=use_bioclip)

            augmented_embeddings_dict = {
              "embeddings": torch.cat([augmented_embeddings_dict["embeddings"], augmented_embeddings_dict_2["embeddings"]]),
              "labels": torch.cat([augmented_embeddings_dict["labels"], augmented_embeddings_dict_2["labels"]]),
              "ids": torch.cat([augmented_embeddings_dict["ids"], augmented_embeddings_dict_2["ids"]])
            }

        else:
          augmented_embeddings_dict=None

        if debug_subset_size is not None:
          print(f"⚠ Debug mode: using only the first {debug_subset_size} embeddings.")
          embeddings_dict['embeddings'] = embeddings_dict['embeddings'][:debug_subset_size]
          embeddings_dict['labels'] = embeddings_dict['labels'][:debug_subset_size]
          embeddings_dict['ids'] = embeddings_dict['ids'][:debug_subset_size]

          if augmentation:
            augmented_embeddings_dict['embeddings'] = augmented_embeddings_dict['embeddings'][:debug_subset_size]
            augmented_embeddings_dict['labels'] = augmented_embeddings_dict['labels'][:debug_subset_size]
            augmented_embeddings_dict['ids'] = augmented_embeddings_dict['ids'][:debug_subset_size]
          else:
            augmented_embeddings_dict=None


        #to this function I will pass both extracted embeddings and augmented embeddings (if they exist)
        embeddings_train_loader, embeddings_val_loader, class_weights, input_size = split_embeddings(embeddings_dict, augmented_embeddings_dict, val_percentage=0.2)

    else:

        img_loader = get_data_loader(root_dir=github_repository)
        print("Dataloader obtained..")

        #this function also saves embeddings in the desired path
        #input size is the same for training and validation, is is the size (number of features) of the single embedding.
        embeddings_dict = extract_embeddings(dataloader=img_loader, embeddings_extractor=feature_extractor, device=device, embeddings_save_path=embeddings_save_path, use_bioclip=use_bioclip)

        if augmentation:
          #only extract embeddings for augmentated data
          augmented_loader = get_data_loader_augmented(root_dir=github_repository)
          augmented_embeddings_dict = extract_embeddings(augmented_loader, feature_extractor, device, embeddings_save_path=embeddings_save_path, augmented=True, use_bioclip=use_bioclip)

          if augmentation_factor==3:
            augmented_loader_2 = get_data_loader_augmented(root_dir=github_repository, augmentation='jittering')
            augmented_embeddings_dict_2 = extract_embeddings(augmented_loader_2, feature_extractor, device, embeddings_save_path=embeddings_save_path, augmented=True, use_bioclip=use_bioclip)

            augmented_embeddings_dict = {
              "embeddings": torch.cat([augmented_embeddings_dict["embeddings"], augmented_embeddings_dict_2["embeddings"]]),
              "labels": torch.cat([augmented_embeddings_dict["labels"], augmented_embeddings_dict_2["labels"]]),
              "ids": torch.cat([augmented_embeddings_dict["ids"], augmented_embeddings_dict_2["ids"]])
            }

        else:
          augmented_embeddings_dict=None

        if debug_subset_size is not None:
          print(f"⚠ Debug mode: using only the first {debug_subset_size} embeddings.")
          embeddings_dict['embeddings'] = embeddings_dict['embeddings'][:debug_subset_size]
          embeddings_dict['labels'] = embeddings_dict['labels'][:debug_subset_size]
          embeddings_dict['ids'] = embeddings_dict['ids'][:debug_subset_size]

          if augmentation:
            augmented_embeddings_dict['embeddings'] = augmented_embeddings_dict['embeddings'][:debug_subset_size]
            augmented_embeddings_dict['labels'] = augmented_embeddings_dict['labels'][:debug_subset_size]
            augmented_embeddings_dict['ids'] = augmented_embeddings_dict['ids'][:debug_subset_size]
          else:
            augmented_embeddings_dict=None

        embeddings_train_loader, embeddings_val_loader, class_weights, input_size = split_embeddings(embeddings_dict, augmented_embeddings_dict, val_percentage=0.2)


    classifier = InvasiveSpeciesClassifier(embedding_dim=input_size).to(device)
    if loss_type=='CE':
      criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
    elif loss_type=='FL':
       criterion = FocalLoss(alpha=class_weights.to(device), gamma=2, reduction='mean')
    optimizer = optim.Adam(classifier.parameters(), lr=1e-4)


    train_losses, train_accuracies, val_losses, val_accuracies, report_dict = train_classifier(
        train_loader=embeddings_train_loader,
        val_loader=embeddings_val_loader,
        feature_extractor=feature_extractor,
        classifier=classifier,
        criterion=criterion,
        optimizer=optimizer,
        device=device,
        output_dir=output_dir,
        model_name=model_name,
        num_epoch=epochs,
        verbose=verbose,
        save_classifier=save_model,
        do_early_stopping=do_early_stopping
    )

    # Save results
    save_training_log(model_name, output_dir, train_losses, val_losses, train_accuracies, val_accuracies, report_dict)

    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, 'bo-', label='Train Loss')
    plt.plot(epochs, val_losses, 'ro-', label='Val Loss')
    plt.title("Loss over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, 'bo-', label='Train Accuracy')
    plt.plot(epochs, val_accuracies, 'ro-', label='Val Accuracy')
    plt.title("Accuracy over Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

    full_model = FullModel(feature_extractor, classifier)
    print("Full model built...")
    full_model.eval()

    if save_model:
      torch.save(full_model.state_dict(), f'full_{model_name}.pth')
      google_drive_path = f'/content/drive/MyDrive/Thesis/{output_dir}/full_{model_name}.pth'
      torch.save(full_model.state_dict(), google_drive_path)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Total execution time: {elapsed_time:.2f} seconds")

    #return the validation loss and accuracy for the last epoch
    return val_losses[-1], val_accuracies[-1]

# %%
model_name = "new_resnet_test"
embeddings_save_path = '/content/drive/MyDrive/Thesis/NEW_resnet_embeddings.pt'
create_model_and_predict(folder_name="taxas", use_bioclip=False, augmentation=False, output_dir="invasive_species",
                         model_name=model_name, save_model=False, embeddings_save_path=embeddings_save_path,
                         epochs=50, debug_subset_size=None, do_early_stopping=True)
# Out:
# Using device: cuda
# Model obtained...
# Feature extractor obtained..
# ✅ Embeddings already exist, loading from file...
# 🔢 Class distribution in train set: Counter({0: 19898, 1: 16390})
# ⚖️ Class weights: tensor([0.1010, 0.1030])
#
# 🔁 Epoch 1/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 523.25it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1138.90it/s]
# 📉 Train Loss: 0.5880 | Accuracy: 0.6799
# 📈 Val Loss:   0.5498 | Accuracy: 0.7087
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.77      0.66      0.71      4935
# Non Invasive       0.65      0.77      0.71      4138
#
#     accuracy                           0.71      9073
#    macro avg       0.71      0.71      0.71      9073
# weighted avg       0.72      0.71      0.71      9073
# 🔁 Epoch 2/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 519.94it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1109.48it/s]
# 📉 Train Loss: 0.5421 | Accuracy: 0.7199
# 📈 Val Loss:   0.5241 | Accuracy: 0.7355
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.72      0.84      0.78      4935
# Non Invasive       0.76      0.61      0.68      4138
#
#     accuracy                           0.74      9073
#    macro avg       0.74      0.73      0.73      9073
# weighted avg       0.74      0.74      0.73      9073
# 🔁 Epoch 3/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 517.02it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1048.08it/s]
# 📉 Train Loss: 0.5189 | Accuracy: 0.7378
# 📈 Val Loss:   0.5056 | Accuracy: 0.7435
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.79      0.71      0.75      4935
# Non Invasive       0.69      0.78      0.74      4138
#
#     accuracy                           0.74      9073
#    macro avg       0.74      0.75      0.74      9073
# weighted avg       0.75      0.74      0.74      9073
# 🔁 Epoch 4/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 457.23it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 820.51it/s]
# 📉 Train Loss: 0.5039 | Accuracy: 0.7495
# 📈 Val Loss:   0.4933 | Accuracy: 0.7563
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.76      0.81      0.78      4935
# Non Invasive       0.75      0.69      0.72      4138
#
#     accuracy                           0.76      9073
#    macro avg       0.76      0.75      0.75      9073
# weighted avg       0.76      0.76      0.76      9073
# 🔁 Epoch 5/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 468.22it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1066.26it/s]
# 📉 Train Loss: 0.4899 | Accuracy: 0.7580
# 📈 Val Loss:   0.4997 | Accuracy: 0.7532
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.73      0.87      0.79      4935
# Non Invasive       0.80      0.62      0.70      4138
#
#     accuracy                           0.75      9073
#    macro avg       0.76      0.74      0.74      9073
# weighted avg       0.76      0.75      0.75      9073
# 🔁 Epoch 6/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 511.05it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1011.77it/s]
# 📉 Train Loss: 0.4801 | Accuracy: 0.7641
# 📈 Val Loss:   0.4850 | Accuracy: 0.7666
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.76      0.83      0.80      4935
# Non Invasive       0.77      0.69      0.73      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.76      0.76      9073
# weighted avg       0.77      0.77      0.76      9073
# 🔁 Epoch 7/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 516.40it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1113.03it/s]
# 📉 Train Loss: 0.4713 | Accuracy: 0.7692
# 📈 Val Loss:   0.4787 | Accuracy: 0.7627
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.79      0.78      0.78      4935
# Non Invasive       0.74      0.75      0.74      4138
#
#     accuracy                           0.76      9073
#    macro avg       0.76      0.76      0.76      9073
# weighted avg       0.76      0.76      0.76      9073
# 🔁 Epoch 8/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 510.53it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1082.37it/s]
# 📉 Train Loss: 0.4623 | Accuracy: 0.7775
# 📈 Val Loss:   0.4722 | Accuracy: 0.7694
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.78      0.81      0.79      4935
# Non Invasive       0.76      0.72      0.74      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.77      0.77      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 9/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 419.74it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 700.14it/s]
# 📉 Train Loss: 0.4536 | Accuracy: 0.7825
# 📈 Val Loss:   0.4748 | Accuracy: 0.7691
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.76      0.84      0.80      4935
# Non Invasive       0.78      0.69      0.73      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.76      0.76      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 10/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 508.17it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1032.58it/s]
# 📉 Train Loss: 0.4469 | Accuracy: 0.7877
# 📈 Val Loss:   0.4714 | Accuracy: 0.7651
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.79      0.78      0.78      4935
# Non Invasive       0.74      0.75      0.74      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.76      0.76      0.76      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 11/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 514.74it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1094.94it/s]
# 📉 Train Loss: 0.4389 | Accuracy: 0.7913
# 📈 Val Loss:   0.4710 | Accuracy: 0.7692
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.79      0.78      0.79      4935
# Non Invasive       0.74      0.75      0.75      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.77      0.77      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 12/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 497.97it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1009.04it/s]
# 📉 Train Loss: 0.4339 | Accuracy: 0.7952
# 📈 Val Loss:   0.4653 | Accuracy: 0.7733
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.78      0.81      0.80      4935
# Non Invasive       0.76      0.73      0.75      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.77      0.77      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 13/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 500.20it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 774.21it/s]
# 📉 Train Loss: 0.4247 | Accuracy: 0.8010
# 📈 Val Loss:   0.4671 | Accuracy: 0.7736
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.77      0.84      0.80      4935
# Non Invasive       0.79      0.69      0.74      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.78      0.77      0.77      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 14/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 388.45it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 994.33it/s]
# 📉 Train Loss: 0.4191 | Accuracy: 0.8050
# 📈 Val Loss:   0.4629 | Accuracy: 0.7703
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.80      0.76      0.78      4935
# Non Invasive       0.73      0.78      0.76      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.77      0.77      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 15/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 506.13it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1046.95it/s]
# 📉 Train Loss: 0.4101 | Accuracy: 0.8113
# 📈 Val Loss:   0.4637 | Accuracy: 0.7726
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.82      0.75      0.78      4935
# Non Invasive       0.73      0.80      0.76      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.77      0.77      9073
# weighted avg       0.78      0.77      0.77      9073
# 🔁 Epoch 16/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 492.16it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1042.93it/s]
# 📉 Train Loss: 0.4041 | Accuracy: 0.8139
# 📈 Val Loss:   0.4615 | Accuracy: 0.7749
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.79      0.80      0.79      4935
# Non Invasive       0.76      0.75      0.75      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.77      0.77      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 17/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 451.36it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 968.59it/s]
# 📉 Train Loss: 0.3974 | Accuracy: 0.8167
# 📈 Val Loss:   0.4655 | Accuracy: 0.7728
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.82      0.75      0.78      4935
# Non Invasive       0.73      0.81      0.76      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.78      0.77      9073
# weighted avg       0.78      0.77      0.77      9073
# 🔁 Epoch 18/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 432.35it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 793.78it/s]
# 📉 Train Loss: 0.3902 | Accuracy: 0.8217
# 📈 Val Loss:   0.4631 | Accuracy: 0.7735
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.79      0.80      0.79      4935
# Non Invasive       0.76      0.74      0.75      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.77      0.77      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 19/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 454.15it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1031.67it/s]
# 📉 Train Loss: 0.3832 | Accuracy: 0.8266
# 📈 Val Loss:   0.4756 | Accuracy: 0.7724
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.75      0.88      0.81      4935
# Non Invasive       0.82      0.65      0.72      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.78      0.76      0.76      9073
# weighted avg       0.78      0.77      0.77      9073
# 🔁 Epoch 20/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 505.68it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1080.09it/s]
# 📉 Train Loss: 0.3783 | Accuracy: 0.8288
# 📈 Val Loss:   0.4605 | Accuracy: 0.7786
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.81      0.78      0.79      4935
# Non Invasive       0.75      0.78      0.76      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.78      0.78      9073
# weighted avg       0.78      0.78      0.78      9073
# 🔁 Epoch 21/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 498.86it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1041.36it/s]
# 📉 Train Loss: 0.3705 | Accuracy: 0.8342
# 📈 Val Loss:   0.4677 | Accuracy: 0.7693
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.81      0.75      0.78      4935
# Non Invasive       0.73      0.80      0.76      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.77      0.77      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 22/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 507.48it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1053.62it/s]
# 📉 Train Loss: 0.3647 | Accuracy: 0.8399
# 📈 Val Loss:   0.4662 | Accuracy: 0.7724
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.83      0.73      0.78      4935
# Non Invasive       0.72      0.82      0.77      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.78      0.77      9073
# weighted avg       0.78      0.77      0.77      9073
# 🔁 Epoch 23/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 412.20it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 674.48it/s]
# 📉 Train Loss: 0.3571 | Accuracy: 0.8420
# 📈 Val Loss:   0.4620 | Accuracy: 0.7781
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.78      0.82      0.80      4935
# Non Invasive       0.77      0.73      0.75      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.77      0.78      9073
# weighted avg       0.78      0.78      0.78      9073
# 🔁 Epoch 24/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 500.79it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1035.45it/s]
# 📉 Train Loss: 0.3512 | Accuracy: 0.8463
# 📈 Val Loss:   0.4647 | Accuracy: 0.7757
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.80      0.78      0.79      4935
# Non Invasive       0.75      0.77      0.76      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.77      0.77      0.77      9073
# weighted avg       0.78      0.78      0.78      9073
# 🔁 Epoch 25/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 492.49it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1053.59it/s]
# 📉 Train Loss: 0.3444 | Accuracy: 0.8501
# 📈 Val Loss:   0.4601 | Accuracy: 0.7822
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.80      0.80      0.80      4935
# Non Invasive       0.76      0.76      0.76      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.78      0.78      9073
# weighted avg       0.78      0.78      0.78      9073
# 🔁 Epoch 26/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 506.11it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 977.69it/s]
# 📉 Train Loss: 0.3369 | Accuracy: 0.8542
# 📈 Val Loss:   0.4720 | Accuracy: 0.7786
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.77      0.85      0.81      4935
# Non Invasive       0.80      0.69      0.74      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.77      0.77      9073
# weighted avg       0.78      0.78      0.78      9073
# 🔁 Epoch 27/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 382.05it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 742.99it/s]
# 📉 Train Loss: 0.3313 | Accuracy: 0.8570
# 📈 Val Loss:   0.4676 | Accuracy: 0.7771
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.79      0.81      0.80      4935
# Non Invasive       0.76      0.74      0.75      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.77      0.77      9073
# weighted avg       0.78      0.78      0.78      9073
# 🔁 Epoch 28/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 442.24it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 974.83it/s]
# 📉 Train Loss: 0.3254 | Accuracy: 0.8611
# 📈 Val Loss:   0.4640 | Accuracy: 0.7840
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.79      0.82      0.80      4935
# Non Invasive       0.77      0.74      0.76      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.78      0.78      9073
# weighted avg       0.78      0.78      0.78      9073
# 🔁 Epoch 29/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 502.37it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1022.67it/s]
# 📉 Train Loss: 0.3178 | Accuracy: 0.8651
# 📈 Val Loss:   0.4713 | Accuracy: 0.7787
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.78      0.83      0.80      4935
# Non Invasive       0.78      0.71      0.75      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.77      0.77      9073
# weighted avg       0.78      0.78      0.78      9073
# 🔁 Epoch 30/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 501.18it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1006.73it/s]
# 📉 Train Loss: 0.3113 | Accuracy: 0.8693
# 📈 Val Loss:   0.4776 | Accuracy: 0.7761
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.78      0.82      0.80      4935
# Non Invasive       0.77      0.73      0.75      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.77      0.77      9073
# weighted avg       0.78      0.78      0.78      9073
# 🔁 Epoch 31/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 500.75it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 969.93it/s]
# 📉 Train Loss: 0.3056 | Accuracy: 0.8724
# 📈 Val Loss:   0.4823 | Accuracy: 0.7756
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.77      0.84      0.80      4935
# Non Invasive       0.79      0.69      0.74      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.77      0.77      9073
# weighted avg       0.78      0.78      0.77      9073
# 🔁 Epoch 32/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 421.86it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 749.38it/s]
# 📉 Train Loss: 0.2973 | Accuracy: 0.8773
# 📈 Val Loss:   0.4758 | Accuracy: 0.7807
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.80      0.79      0.80      4935
# Non Invasive       0.75      0.77      0.76      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.78      0.78      9073
# weighted avg       0.78      0.78      0.78      9073
# 🔁 Epoch 33/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 453.17it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 970.76it/s]
# 📉 Train Loss: 0.2924 | Accuracy: 0.8789
# 📈 Val Loss:   0.4966 | Accuracy: 0.7736
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.77      0.84      0.80      4935
# Non Invasive       0.79      0.69      0.74      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.78      0.77      0.77      9073
# weighted avg       0.77      0.77      0.77      9073
# 🔁 Epoch 34/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 494.45it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 991.63it/s]
# 📉 Train Loss: 0.2861 | Accuracy: 0.8841
# 📈 Val Loss:   0.5028 | Accuracy: 0.7662
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.85      0.70      0.76      4935
# Non Invasive       0.70      0.85      0.77      4138
#
#     accuracy                           0.77      9073
#    macro avg       0.77      0.77      0.77      9073
# weighted avg       0.78      0.77      0.77      9073
# 🔁 Epoch 35/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 492.70it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1009.67it/s]
# 📉 Train Loss: 0.2815 | Accuracy: 0.8853
# 📈 Val Loss:   0.4833 | Accuracy: 0.7788
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.81      0.78      0.79      4935
# Non Invasive       0.75      0.77      0.76      4138
#
#     accuracy                           0.78      9073
#    macro avg       0.78      0.78      0.78      9073
# weighted avg       0.78      0.78      0.78      9073
# Stopping early as no improvement has been observed.
# Early stopping at epoch 34
# 📝 Appended log to /content/drive/MyDrive/Thesis/invasive_species/logs/training_log.json
# Full model built...
# Total execution time: 108.24 seconds
# (0.48328242472221133, 0.7787942246225064)

# %%
model_name_BC1 = "new_bioclip_1_test"
embeddings_save_path_BC1 = '/content/drive/MyDrive/Thesis/NEW_bioclip_1_embeddings.pt'
create_model_and_predict(folder_name="taxas", use_bioclip=True, bioclip_version=1, augmentation=False,
                         output_dir="invasive_species", model_name=model_name_BC1, save_model=False, epochs=50,
                         embeddings_save_path=embeddings_save_path_BC1, debug_subset_size=None, do_early_stopping=True)
# Out:
# Using device: cuda
# open_clip_config.json:   0%|          | 0.00/469 [00:00<?, ?B/s]
# open_clip_pytorch_model.bin:   0%|          | 0.00/599M [00:00<?, ?B/s]
# Model obtained...
# Feature extractor obtained..
# Dataloader obtained..
# Extracting embeddings: 100%|██████████| 1418/1418 [12:14<00:00,  1.93it/s]
# 🔢 Class distribution in train set: Counter({0: 19838, 1: 16450})
# ⚖️ Class weights: tensor([0.1011, 0.1030])
#
# 🔁 Epoch 1/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 446.81it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 740.43it/s]
# 📉 Train Loss: 0.4493 | Accuracy: 0.8041
# 📈 Val Loss:   0.3472 | Accuracy: 0.8477
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.84      0.90      0.87      4995
# Non Invasive       0.86      0.79      0.82      4078
#
#     accuracy                           0.85      9073
#    macro avg       0.85      0.84      0.84      9073
# weighted avg       0.85      0.85      0.85      9073
# 🔁 Epoch 2/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 432.49it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 852.34it/s]
# 📉 Train Loss: 0.3143 | Accuracy: 0.8660
# 📈 Val Loss:   0.2985 | Accuracy: 0.8785
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.89      0.89      0.89      4995
# Non Invasive       0.87      0.86      0.86      4078
#
#     accuracy                           0.88      9073
#    macro avg       0.88      0.88      0.88      9073
# weighted avg       0.88      0.88      0.88      9073
# 🔁 Epoch 3/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 500.08it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1138.22it/s]
# 📉 Train Loss: 0.2794 | Accuracy: 0.8828
# 📈 Val Loss:   0.2728 | Accuracy: 0.8897
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.89      0.91      0.90      4995
# Non Invasive       0.89      0.86      0.88      4078
#
#     accuracy                           0.89      9073
#    macro avg       0.89      0.89      0.89      9073
# weighted avg       0.89      0.89      0.89      9073
# 🔁 Epoch 4/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 509.13it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1086.06it/s]
# 📉 Train Loss: 0.2585 | Accuracy: 0.8935
# 📈 Val Loss:   0.2569 | Accuracy: 0.8953
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.90      0.92      0.91      4995
# Non Invasive       0.90      0.87      0.88      4078
#
#     accuracy                           0.90      9073
#    macro avg       0.90      0.89      0.89      9073
# weighted avg       0.90      0.90      0.90      9073
# 🔁 Epoch 5/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 513.79it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1086.96it/s]
# 📉 Train Loss: 0.2448 | Accuracy: 0.8998
# 📈 Val Loss:   0.2467 | Accuracy: 0.8992
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.90      0.92      0.91      4995
# Non Invasive       0.90      0.87      0.89      4078
#
#     accuracy                           0.90      9073
#    macro avg       0.90      0.90      0.90      9073
# weighted avg       0.90      0.90      0.90      9073
# 🔁 Epoch 6/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 437.07it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 720.85it/s]
# 📉 Train Loss: 0.2354 | Accuracy: 0.9048
# 📈 Val Loss:   0.2405 | Accuracy: 0.9000
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.90      0.92      0.91      4995
# Non Invasive       0.90      0.88      0.89      4078
#
#     accuracy                           0.90      9073
#    macro avg       0.90      0.90      0.90      9073
# weighted avg       0.90      0.90      0.90      9073
# 🔁 Epoch 7/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 511.87it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1021.50it/s]
# 📉 Train Loss: 0.2283 | Accuracy: 0.9078
# 📈 Val Loss:   0.2345 | Accuracy: 0.9021
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.92      0.91      4995
# Non Invasive       0.90      0.89      0.89      4078
#
#     accuracy                           0.90      9073
#    macro avg       0.90      0.90      0.90      9073
# weighted avg       0.90      0.90      0.90      9073
# 🔁 Epoch 8/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 510.78it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1084.90it/s]
# 📉 Train Loss: 0.2229 | Accuracy: 0.9096
# 📈 Val Loss:   0.2318 | Accuracy: 0.9023
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.90      0.92      0.91      4995
# Non Invasive       0.90      0.87      0.89      4078
#
#     accuracy                           0.90      9073
#    macro avg       0.90      0.90      0.90      9073
# weighted avg       0.90      0.90      0.90      9073
# 🔁 Epoch 9/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 514.93it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1083.19it/s]
# 📉 Train Loss: 0.2186 | Accuracy: 0.9114
# 📈 Val Loss:   0.2283 | Accuracy: 0.9047
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.92      0.91      4995
# Non Invasive       0.90      0.88      0.89      4078
#
#     accuracy                           0.90      9073
#    macro avg       0.90      0.90      0.90      9073
# weighted avg       0.90      0.90      0.90      9073
# 🔁 Epoch 10/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 461.71it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 784.23it/s]
# 📉 Train Loss: 0.2147 | Accuracy: 0.9132
# 📈 Val Loss:   0.2260 | Accuracy: 0.9060
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.92      0.91      4995
# Non Invasive       0.90      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.90      0.90      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 11/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 448.86it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1074.50it/s]
# 📉 Train Loss: 0.2113 | Accuracy: 0.9156
# 📈 Val Loss:   0.2234 | Accuracy: 0.9082
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.91      0.92      4995
# Non Invasive       0.89      0.90      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 12/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 512.32it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1011.35it/s]
# 📉 Train Loss: 0.2081 | Accuracy: 0.9170
# 📈 Val Loss:   0.2218 | Accuracy: 0.9092
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.92      0.92      4995
# Non Invasive       0.90      0.90      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 13/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 497.92it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1061.06it/s]
# 📉 Train Loss: 0.2054 | Accuracy: 0.9175
# 📈 Val Loss:   0.2203 | Accuracy: 0.9095
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.93      0.92      4995
# Non Invasive       0.91      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 14/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 509.77it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1082.44it/s]
# 📉 Train Loss: 0.2025 | Accuracy: 0.9193
# 📈 Val Loss:   0.2194 | Accuracy: 0.9085
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.93      0.92      4995
# Non Invasive       0.91      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 15/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 422.27it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 761.35it/s]
# 📉 Train Loss: 0.2003 | Accuracy: 0.9202
# 📈 Val Loss:   0.2171 | Accuracy: 0.9106
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.93      0.92      4995
# Non Invasive       0.91      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 16/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 482.51it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1058.50it/s]
# 📉 Train Loss: 0.1976 | Accuracy: 0.9210
# 📈 Val Loss:   0.2162 | Accuracy: 0.9109
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.93      0.92      4995
# Non Invasive       0.91      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 17/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 495.42it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1052.35it/s]
# 📉 Train Loss: 0.1951 | Accuracy: 0.9231
# 📈 Val Loss:   0.2162 | Accuracy: 0.9109
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.92      0.92      4995
# Non Invasive       0.91      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 18/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 507.36it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1052.04it/s]
# 📉 Train Loss: 0.1930 | Accuracy: 0.9237
# 📈 Val Loss:   0.2146 | Accuracy: 0.9112
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.93      0.92      4995
# Non Invasive       0.91      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 19/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 498.73it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 751.56it/s]
# 📉 Train Loss: 0.1907 | Accuracy: 0.9251
# 📈 Val Loss:   0.2129 | Accuracy: 0.9124
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.92      4995
# Non Invasive       0.91      0.90      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 20/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 404.47it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1052.67it/s]
# 📉 Train Loss: 0.1886 | Accuracy: 0.9257
# 📈 Val Loss:   0.2127 | Accuracy: 0.9133
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.93      0.92      4995
# Non Invasive       0.91      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 21/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 507.61it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1046.79it/s]
# 📉 Train Loss: 0.1863 | Accuracy: 0.9264
# 📈 Val Loss:   0.2117 | Accuracy: 0.9130
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.93      0.92      4995
# Non Invasive       0.91      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 22/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 511.25it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1038.43it/s]
# 📉 Train Loss: 0.1842 | Accuracy: 0.9276
# 📈 Val Loss:   0.2109 | Accuracy: 0.9140
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.92      0.92      4995
# Non Invasive       0.91      0.90      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 23/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 503.29it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1011.94it/s]
# 📉 Train Loss: 0.1822 | Accuracy: 0.9286
# 📈 Val Loss:   0.2120 | Accuracy: 0.9126
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.93      0.92      4995
# Non Invasive       0.91      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 24/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 451.72it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 697.93it/s]
# 📉 Train Loss: 0.1803 | Accuracy: 0.9297
# 📈 Val Loss:   0.2102 | Accuracy: 0.9134
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.93      0.92      4995
# Non Invasive       0.91      0.89      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 25/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 425.47it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 974.58it/s]
# 📉 Train Loss: 0.1784 | Accuracy: 0.9313
# 📈 Val Loss:   0.2093 | Accuracy: 0.9143
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.92      0.92      4995
# Non Invasive       0.91      0.90      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 26/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 502.79it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1040.37it/s]
# 📉 Train Loss: 0.1763 | Accuracy: 0.9320
# 📈 Val Loss:   0.2079 | Accuracy: 0.9158
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.92      4995
# Non Invasive       0.92      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.91      0.91      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 27/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 494.12it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1041.01it/s]
# 📉 Train Loss: 0.1743 | Accuracy: 0.9329
# 📈 Val Loss:   0.2091 | Accuracy: 0.9136
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.94      0.92      4995
# Non Invasive       0.92      0.88      0.90      4078
#
#     accuracy                           0.91      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.91      0.91      9073
# 🔁 Epoch 28/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 494.51it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 990.62it/s]
# 📉 Train Loss: 0.1721 | Accuracy: 0.9338
# 📈 Val Loss:   0.2065 | Accuracy: 0.9161
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.92      4995
# Non Invasive       0.91      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.91      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 29/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 420.32it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 752.55it/s]
# 📉 Train Loss: 0.1706 | Accuracy: 0.9351
# 📈 Val Loss:   0.2066 | Accuracy: 0.9170
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.93      4995
# Non Invasive       0.92      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 30/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 477.98it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1029.79it/s]
# 📉 Train Loss: 0.1684 | Accuracy: 0.9360
# 📈 Val Loss:   0.2049 | Accuracy: 0.9195
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.93      4995
# Non Invasive       0.92      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 31/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 502.90it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1008.03it/s]
# 📉 Train Loss: 0.1667 | Accuracy: 0.9366
# 📈 Val Loss:   0.2066 | Accuracy: 0.9167
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.92      0.92      4995
# Non Invasive       0.90      0.92      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 32/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 500.44it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 982.99it/s]
# 📉 Train Loss: 0.1646 | Accuracy: 0.9383
# 📈 Val Loss:   0.2053 | Accuracy: 0.9178
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.93      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 33/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 483.12it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 784.44it/s]
# 📉 Train Loss: 0.1625 | Accuracy: 0.9388
# 📈 Val Loss:   0.2047 | Accuracy: 0.9173
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 34/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 404.51it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 970.65it/s]
# 📉 Train Loss: 0.1609 | Accuracy: 0.9395
# 📈 Val Loss:   0.2032 | Accuracy: 0.9194
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 35/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 492.78it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 986.59it/s]
# 📉 Train Loss: 0.1590 | Accuracy: 0.9414
# 📈 Val Loss:   0.2025 | Accuracy: 0.9200
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 36/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 495.89it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1005.50it/s]
# 📉 Train Loss: 0.1571 | Accuracy: 0.9416
# 📈 Val Loss:   0.2038 | Accuracy: 0.9189
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.92      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 37/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 487.19it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 958.95it/s]
# 📉 Train Loss: 0.1551 | Accuracy: 0.9422
# 📈 Val Loss:   0.2027 | Accuracy: 0.9191
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.94      0.93      4995
# Non Invasive       0.92      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 38/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 414.34it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 720.16it/s]
# 📉 Train Loss: 0.1535 | Accuracy: 0.9433
# 📈 Val Loss:   0.2032 | Accuracy: 0.9199
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.93      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 39/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 437.40it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1020.36it/s]
# 📉 Train Loss: 0.1514 | Accuracy: 0.9443
# 📈 Val Loss:   0.2012 | Accuracy: 0.9198
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.93      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 40/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 495.91it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1015.66it/s]
# 📉 Train Loss: 0.1497 | Accuracy: 0.9452
# 📈 Val Loss:   0.2012 | Accuracy: 0.9190
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.93      4995
# Non Invasive       0.92      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 41/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 494.40it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1002.13it/s]
# 📉 Train Loss: 0.1478 | Accuracy: 0.9468
# 📈 Val Loss:   0.2020 | Accuracy: 0.9187
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 42/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 488.64it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1001.73it/s]
# 📉 Train Loss: 0.1459 | Accuracy: 0.9474
# 📈 Val Loss:   0.2009 | Accuracy: 0.9194
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.92      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 43/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 414.48it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 649.07it/s]
# 📉 Train Loss: 0.1441 | Accuracy: 0.9475
# 📈 Val Loss:   0.2028 | Accuracy: 0.9183
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.94      0.93      4995
# Non Invasive       0.92      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 44/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 476.32it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 988.77it/s]
# 📉 Train Loss: 0.1426 | Accuracy: 0.9491
# 📈 Val Loss:   0.2022 | Accuracy: 0.9174
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.94      0.93      4995
# Non Invasive       0.92      0.89      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 45/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 474.41it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 914.45it/s]
# 📉 Train Loss: 0.1406 | Accuracy: 0.9492
# 📈 Val Loss:   0.2008 | Accuracy: 0.9194
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.93      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 46/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 488.98it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 981.93it/s]
# 📉 Train Loss: 0.1388 | Accuracy: 0.9510
# 📈 Val Loss:   0.2017 | Accuracy: 0.9181
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.93      4995
# Non Invasive       0.92      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 47/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 462.99it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 760.86it/s]
# 📉 Train Loss: 0.1370 | Accuracy: 0.9517
# 📈 Val Loss:   0.2007 | Accuracy: 0.9205
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.93      0.93      4995
# Non Invasive       0.91      0.91      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 48/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 398.59it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 979.76it/s]
# 📉 Train Loss: 0.1352 | Accuracy: 0.9526
# 📈 Val Loss:   0.1993 | Accuracy: 0.9201
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.93      4995
# Non Invasive       0.92      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 49/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 492.93it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 970.02it/s]
# 📉 Train Loss: 0.1335 | Accuracy: 0.9536
# 📈 Val Loss:   0.2001 | Accuracy: 0.9187
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.94      0.93      4995
# Non Invasive       0.92      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 50/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 491.64it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 968.27it/s]
# 📉 Train Loss: 0.1315 | Accuracy: 0.9547
# 📈 Val Loss:   0.2003 | Accuracy: 0.9183
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.94      0.93      4995
# Non Invasive       0.92      0.90      0.91      4078
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 📝 Appended log to /content/drive/MyDrive/Thesis/invasive_species/logs/training_log.json
# Full model built...
# Total execution time: 906.54 seconds
# (0.20026794553236624, 0.9183291083434366)

# %%
model_name_BC2 = "new_bioclip_2_test"
embeddings_save_path_BC2 = '/content/drive/MyDrive/Thesis/NEW_bioclip_2_embeddings.pt'
create_model_and_predict(folder_name="taxas", use_bioclip=True, augmentation=False, bioclip_version=2,
                         output_dir="invasive_species", model_name=model_name, save_model=False, epochs=50,
                         embeddings_save_path=embeddings_save_path_BC2, debug_subset_size=None, do_early_stopping=True)
# Out:
# Using device: cuda
# BioCLIP 2!
# open_clip_config.json:   0%|          | 0.00/534 [00:00<?, ?B/s]
# open_clip_model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# Model obtained...
# Feature extractor obtained..
# Dataloader obtained..
# Extracting embeddings: 100%|██████████| 1418/1418 [37:23<00:00,  1.58s/it]
# 🔢 Class distribution in train set: Counter({0: 19888, 1: 16400})
# ⚖️ Class weights: tensor([0.1010, 0.1030])
#
# 🔁 Epoch 1/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 450.82it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 773.21it/s]
# 📉 Train Loss: 0.3749 | Accuracy: 0.8649
# 📈 Val Loss:   0.2463 | Accuracy: 0.9034
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.90      0.92      0.91      4945
# Non Invasive       0.91      0.88      0.89      4128
#
#     accuracy                           0.90      9073
#    macro avg       0.90      0.90      0.90      9073
# weighted avg       0.90      0.90      0.90      9073
# 🔁 Epoch 2/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 444.04it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1106.81it/s]
# 📉 Train Loss: 0.2314 | Accuracy: 0.9103
# 📈 Val Loss:   0.2172 | Accuracy: 0.9150
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.92      0.93      0.92      4945
# Non Invasive       0.91      0.90      0.91      4128
#
#     accuracy                           0.92      9073
#    macro avg       0.91      0.91      0.91      9073
# weighted avg       0.91      0.92      0.91      9073
# 🔁 Epoch 3/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 507.36it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1116.41it/s]
# 📉 Train Loss: 0.2111 | Accuracy: 0.9178
# 📈 Val Loss:   0.2036 | Accuracy: 0.9202
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.92      0.93      4945
# Non Invasive       0.91      0.92      0.91      4128
#
#     accuracy                           0.92      9073
#    macro avg       0.92      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 4/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 431.62it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1100.55it/s]
# 📉 Train Loss: 0.1978 | Accuracy: 0.9237
# 📈 Val Loss:   0.1928 | Accuracy: 0.9242
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.91      0.95      0.93      4945
# Non Invasive       0.94      0.89      0.91      4128
#
#     accuracy                           0.92      9073
#    macro avg       0.93      0.92      0.92      9073
# weighted avg       0.92      0.92      0.92      9073
# 🔁 Epoch 5/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 508.45it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1094.37it/s]
# 📉 Train Loss: 0.1873 | Accuracy: 0.9288
# 📈 Val Loss:   0.1818 | Accuracy: 0.9289
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.94      0.94      4945
# Non Invasive       0.93      0.91      0.92      4128
#
#     accuracy                           0.93      9073
#    macro avg       0.93      0.93      0.93      9073
# weighted avg       0.93      0.93      0.93      9073
# 🔁 Epoch 6/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 410.41it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1048.01it/s]
# 📉 Train Loss: 0.1791 | Accuracy: 0.9325
# 📈 Val Loss:   0.1738 | Accuracy: 0.9311
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.95      0.94      4945
# Non Invasive       0.93      0.91      0.92      4128
#
#     accuracy                           0.93      9073
#    macro avg       0.93      0.93      0.93      9073
# weighted avg       0.93      0.93      0.93      9073
# 🔁 Epoch 7/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 501.99it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1097.50it/s]
# 📉 Train Loss: 0.1724 | Accuracy: 0.9355
# 📈 Val Loss:   0.1705 | Accuracy: 0.9339
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.94      0.93      0.94      4945
# Non Invasive       0.92      0.93      0.93      4128
#
#     accuracy                           0.93      9073
#    macro avg       0.93      0.93      0.93      9073
# weighted avg       0.93      0.93      0.93      9073
# 🔁 Epoch 8/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 504.54it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1042.77it/s]
# 📉 Train Loss: 0.1666 | Accuracy: 0.9384
# 📈 Val Loss:   0.1644 | Accuracy: 0.9366
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.94      0.94      0.94      4945
# Non Invasive       0.93      0.93      0.93      4128
#
#     accuracy                           0.94      9073
#    macro avg       0.94      0.94      0.94      9073
# weighted avg       0.94      0.94      0.94      9073
# 🔁 Epoch 9/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 496.24it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1086.80it/s]
# 📉 Train Loss: 0.1616 | Accuracy: 0.9407
# 📈 Val Loss:   0.1598 | Accuracy: 0.9377
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.95      0.94      4945
# Non Invasive       0.94      0.92      0.93      4128
#
#     accuracy                           0.94      9073
#    macro avg       0.94      0.94      0.94      9073
# weighted avg       0.94      0.94      0.94      9073
# 🔁 Epoch 10/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 442.24it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 795.10it/s]
# 📉 Train Loss: 0.1573 | Accuracy: 0.9429
# 📈 Val Loss:   0.1559 | Accuracy: 0.9402
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.94      0.95      0.95      4945
# Non Invasive       0.94      0.93      0.93      4128
#
#     accuracy                           0.94      9073
#    macro avg       0.94      0.94      0.94      9073
# weighted avg       0.94      0.94      0.94      9073
# 🔁 Epoch 11/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 449.52it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1058.08it/s]
# 📉 Train Loss: 0.1531 | Accuracy: 0.9437
# 📈 Val Loss:   0.1531 | Accuracy: 0.9404
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.93      0.96      0.95      4945
# Non Invasive       0.95      0.92      0.93      4128
#
#     accuracy                           0.94      9073
#    macro avg       0.94      0.94      0.94      9073
# weighted avg       0.94      0.94      0.94      9073
# 🔁 Epoch 12/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 498.90it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1028.79it/s]
# 📉 Train Loss: 0.1494 | Accuracy: 0.9462
# 📈 Val Loss:   0.1496 | Accuracy: 0.9436
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.95      0.95      4945
# Non Invasive       0.94      0.94      0.94      4128
#
#     accuracy                           0.94      9073
#    macro avg       0.94      0.94      0.94      9073
# weighted avg       0.94      0.94      0.94      9073
# 🔁 Epoch 13/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 504.76it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1055.46it/s]
# 📉 Train Loss: 0.1457 | Accuracy: 0.9473
# 📈 Val Loss:   0.1463 | Accuracy: 0.9447
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.95      0.95      4945
# Non Invasive       0.94      0.94      0.94      4128
#
#     accuracy                           0.94      9073
#    macro avg       0.94      0.94      0.94      9073
# weighted avg       0.94      0.94      0.94      9073
# 🔁 Epoch 14/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 504.09it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1086.04it/s]
# 📉 Train Loss: 0.1426 | Accuracy: 0.9484
# 📈 Val Loss:   0.1436 | Accuracy: 0.9451
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.94      0.96      0.95      4945
# Non Invasive       0.95      0.92      0.94      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.94      0.94      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 15/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 405.54it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 712.26it/s]
# 📉 Train Loss: 0.1396 | Accuracy: 0.9495
# 📈 Val Loss:   0.1402 | Accuracy: 0.9460
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.94      0.96      0.95      4945
# Non Invasive       0.95      0.93      0.94      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.94      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 16/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 504.73it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1023.51it/s]
# 📉 Train Loss: 0.1364 | Accuracy: 0.9503
# 📈 Val Loss:   0.1399 | Accuracy: 0.9487
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.95      0.95      4945
# Non Invasive       0.94      0.95      0.94      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 17/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 501.78it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 809.30it/s]
# 📉 Train Loss: 0.1341 | Accuracy: 0.9513
# 📈 Val Loss:   0.1364 | Accuracy: 0.9490
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.95      0.95      4945
# Non Invasive       0.94      0.95      0.94      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 18/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 498.22it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1045.01it/s]
# 📉 Train Loss: 0.1316 | Accuracy: 0.9522
# 📈 Val Loss:   0.1346 | Accuracy: 0.9504
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.96      0.95      4945
# Non Invasive       0.95      0.94      0.94      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 19/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 469.93it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 782.10it/s]
# 📉 Train Loss: 0.1293 | Accuracy: 0.9535
# 📈 Val Loss:   0.1329 | Accuracy: 0.9501
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.95      0.95      4945
# Non Invasive       0.94      0.95      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 20/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 420.62it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1029.46it/s]
# 📉 Train Loss: 0.1275 | Accuracy: 0.9538
# 📈 Val Loss:   0.1304 | Accuracy: 0.9516
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.96      0.96      4945
# Non Invasive       0.95      0.94      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 21/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 502.22it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1056.31it/s]
# 📉 Train Loss: 0.1257 | Accuracy: 0.9540
# 📈 Val Loss:   0.1294 | Accuracy: 0.9529
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.96      0.96      4945
# Non Invasive       0.96      0.94      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 22/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 494.76it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1049.38it/s]
# 📉 Train Loss: 0.1239 | Accuracy: 0.9552
# 📈 Val Loss:   0.1282 | Accuracy: 0.9535
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 23/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 497.93it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 997.07it/s]
# 📉 Train Loss: 0.1221 | Accuracy: 0.9558
# 📈 Val Loss:   0.1276 | Accuracy: 0.9536
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.95      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 24/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 424.47it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 805.36it/s]
# 📉 Train Loss: 0.1208 | Accuracy: 0.9563
# 📈 Val Loss:   0.1263 | Accuracy: 0.9546
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 25/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 454.23it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1008.80it/s]
# 📉 Train Loss: 0.1193 | Accuracy: 0.9575
# 📈 Val Loss:   0.1256 | Accuracy: 0.9536
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.96      0.96      4945
# Non Invasive       0.96      0.94      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 26/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 499.88it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1028.24it/s]
# 📉 Train Loss: 0.1178 | Accuracy: 0.9579
# 📈 Val Loss:   0.1247 | Accuracy: 0.9538
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.97      0.96      4945
# Non Invasive       0.96      0.94      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 27/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 498.64it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1043.39it/s]
# 📉 Train Loss: 0.1165 | Accuracy: 0.9583
# 📈 Val Loss:   0.1280 | Accuracy: 0.9532
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.94      0.97      0.96      4945
# Non Invasive       0.97      0.93      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 28/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 493.53it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 906.60it/s]
# 📉 Train Loss: 0.1152 | Accuracy: 0.9589
# 📈 Val Loss:   0.1234 | Accuracy: 0.9556
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 29/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 402.76it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 748.21it/s]
# 📉 Train Loss: 0.1142 | Accuracy: 0.9598
# 📈 Val Loss:   0.1222 | Accuracy: 0.9549
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 30/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 491.08it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1011.33it/s]
# 📉 Train Loss: 0.1127 | Accuracy: 0.9606
# 📈 Val Loss:   0.1231 | Accuracy: 0.9546
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.95      9073
#    macro avg       0.95      0.95      0.95      9073
# weighted avg       0.95      0.95      0.95      9073
# 🔁 Epoch 31/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 495.67it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1034.67it/s]
# 📉 Train Loss: 0.1120 | Accuracy: 0.9601
# 📈 Val Loss:   0.1214 | Accuracy: 0.9554
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.97      0.96      4945
# Non Invasive       0.96      0.94      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.95      0.95      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 32/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 488.95it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 995.55it/s]
# 📉 Train Loss: 0.1107 | Accuracy: 0.9611
# 📈 Val Loss:   0.1223 | Accuracy: 0.9556
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.95      0.96      4945
# Non Invasive       0.95      0.96      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.95      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 33/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 467.48it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 694.24it/s]
# 📉 Train Loss: 0.1099 | Accuracy: 0.9615
# 📈 Val Loss:   0.1193 | Accuracy: 0.9565
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.96      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 34/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 427.33it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 985.96it/s]
# 📉 Train Loss: 0.1088 | Accuracy: 0.9621
# 📈 Val Loss:   0.1201 | Accuracy: 0.9559
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 35/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 486.81it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1020.42it/s]
# 📉 Train Loss: 0.1077 | Accuracy: 0.9625
# 📈 Val Loss:   0.1191 | Accuracy: 0.9558
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 36/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 486.02it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1011.15it/s]
# 📉 Train Loss: 0.1068 | Accuracy: 0.9624
# 📈 Val Loss:   0.1185 | Accuracy: 0.9566
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 37/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 492.78it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 960.64it/s]
# 📉 Train Loss: 0.1058 | Accuracy: 0.9632
# 📈 Val Loss:   0.1185 | Accuracy: 0.9565
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 38/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 421.70it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 773.70it/s]
# 📉 Train Loss: 0.1050 | Accuracy: 0.9633
# 📈 Val Loss:   0.1173 | Accuracy: 0.9562
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.97      0.96      4945
# Non Invasive       0.96      0.94      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 39/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 443.05it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 970.33it/s]
# 📉 Train Loss: 0.1042 | Accuracy: 0.9641
# 📈 Val Loss:   0.1170 | Accuracy: 0.9571
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.96      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 40/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 484.47it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1003.71it/s]
# 📉 Train Loss: 0.1031 | Accuracy: 0.9650
# 📈 Val Loss:   0.1170 | Accuracy: 0.9570
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 41/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 488.32it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 1019.06it/s]
# 📉 Train Loss: 0.1022 | Accuracy: 0.9649
# 📈 Val Loss:   0.1171 | Accuracy: 0.9575
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.97      0.96      4945
# Non Invasive       0.96      0.94      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 42/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 491.32it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 891.48it/s]
# 📉 Train Loss: 0.1018 | Accuracy: 0.9650
# 📈 Val Loss:   0.1163 | Accuracy: 0.9566
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.96      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 43/50
# Training: 100%|██████████| 1134/1134 [00:03<00:00, 377.12it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 697.69it/s]
# 📉 Train Loss: 0.1006 | Accuracy: 0.9657
# 📈 Val Loss:   0.1158 | Accuracy: 0.9573
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.97      0.96      4945
# Non Invasive       0.96      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 44/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 488.18it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 893.28it/s]
# 📉 Train Loss: 0.0997 | Accuracy: 0.9657
# 📈 Val Loss:   0.1168 | Accuracy: 0.9576
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.97      0.96      4945
# Non Invasive       0.96      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 45/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 490.73it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 988.78it/s]
# 📉 Train Loss: 0.0989 | Accuracy: 0.9665
# 📈 Val Loss:   0.1154 | Accuracy: 0.9573
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.96      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 46/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 478.74it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 963.61it/s]
# 📉 Train Loss: 0.0982 | Accuracy: 0.9663
# 📈 Val Loss:   0.1159 | Accuracy: 0.9573
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.95      0.97      0.96      4945
# Non Invasive       0.96      0.94      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 47/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 443.24it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 693.34it/s]
# 📉 Train Loss: 0.0974 | Accuracy: 0.9663
# 📈 Val Loss:   0.1152 | Accuracy: 0.9581
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.96      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 48/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 418.39it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 991.24it/s]
# 📉 Train Loss: 0.0966 | Accuracy: 0.9675
# 📈 Val Loss:   0.1146 | Accuracy: 0.9577
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.97      0.96      4945
# Non Invasive       0.96      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 49/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 484.85it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 994.25it/s]
# 📉 Train Loss: 0.0959 | Accuracy: 0.9672
# 📈 Val Loss:   0.1150 | Accuracy: 0.9569
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.96      0.96      4945
# Non Invasive       0.95      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 🔁 Epoch 50/50
# Training: 100%|██████████| 1134/1134 [00:02<00:00, 485.53it/s]
# Evaluating: 100%|██████████| 284/284 [00:00<00:00, 966.12it/s]
# 📉 Train Loss: 0.0949 | Accuracy: 0.9678
# 📈 Val Loss:   0.1144 | Accuracy: 0.9586
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#     Invasive       0.96      0.97      0.96      4945
# Non Invasive       0.96      0.95      0.95      4128
#
#     accuracy                           0.96      9073
#    macro avg       0.96      0.96      0.96      9073
# weighted avg       0.96      0.96      0.96      9073
# 📝 Appended log to /content/drive/MyDrive/Thesis/invasive_species/logs/training_log.json
# Full model built...
# Total execution time: 2525.73 seconds
# (0.1144148595253379, 0.9585583599691392)

# %% [markdown]
# ### Augmentation Flipping+Jittering

# %%
# epochs=50
# model_name = "epochs_50_augmented_twice"
# embeddings_save_path = '/content/drive/MyDrive/Thesis/resnet_embeddings.pt'
# create_model_and_predict(folder_name="taxas", use_bioclip=False, augmentation=True, output_dir="invasive_species", model_name=model_name, embeddings_save_path=embeddings_save_path, epochs=epochs, debug_subset_size=None)

# %%
# epochs=50
# model_name_BC1 = "epochs_50_augmented_twice"
# embeddings_save_path_BC1 = '/content/drive/MyDrive/Thesis/bioclip_1_embeddings.pt'
# create_model_and_predict(folder_name="taxas", use_bioclip=True, bioclip_version=1, augmentation=True, output_dir="invasive_species", model_name=model_name_BC1, embeddings_save_path=embeddings_save_path_BC1, epochs=epochs, debug_subset_size=None)

# %%
# epochs = 50
# model_name_BC2 = "epochs_50_augmented_twice"
# embeddings_save_path_BC2 = '/content/drive/MyDrive/Thesis/bioclip_2_embeddings.pt'
# create_model_and_predict(folder_name="taxas", use_bioclip=True, augmentation=True, bioclip_version=2, output_dir="invasive_species", model_name=model_name, embeddings_save_path=embeddings_save_path_BC2, epochs=epochs, debug_subset_size=None)

# %% [markdown]
# Hyperparameters:
#
# - epochs
# - augmentation_factor (No, x2, x3)
# - loss (CrossEntropy, FocalLoss)

# %% [markdown]
# ### Grid Search

# %%
augmentation_factors = [2,3]
losses = ['CE', 'FL']
augmentations = [False, True]

best_hp = {
    'augmentation': None,
    'loss_type': None,
    'factor': None,
    'val_loss': None,
    'val_accuracy': None
}

epochs = 50
model_name_BC2 = "hp_tuning_best_BC2"
embeddings_save_path_BC2 = '/content/drive/MyDrive/Thesis/bioclip_2_embeddings.pt'

best_accuracy = None

for loss_type in losses:
    for augmentation in augmentations:

        if not augmentation:
            print(f"Launching model with hyperparameters {augmentation}, {loss_type}")
            val_loss, val_accuracy = create_model_and_predict(
                folder_name="taxas", use_bioclip=True, augmentation=augmentation,
                augmentation_factor=None, loss_type=loss_type,
                bioclip_version=2, output_dir="invasive_species", model_name=model_name_BC2,
                save_model=False, verbose=False, embeddings_save_path=embeddings_save_path_BC2,
                epochs=epochs, debug_subset_size=None
            )

            if best_accuracy is None or val_accuracy > best_accuracy:
                best_accuracy = val_accuracy
                best_hp.update({
                    'augmentation': augmentation,
                    'loss_type': loss_type,
                    'factor': None,
                    'val_loss': val_loss,
                    'val_accuracy': val_accuracy
                })

        else:
            for factor in augmentation_factors:
                print(f"Launching model with hyperparameters {augmentation}, {loss_type}, {factor}")
                val_loss, val_accuracy = create_model_and_predict(
                    folder_name="taxas", use_bioclip=True, augmentation=augmentation,
                    augmentation_factor=factor, loss_type=loss_type,
                    bioclip_version=2, output_dir="invasive_species", model_name=model_name_BC2,
                    save_model=False, verbose=False, embeddings_save_path=embeddings_save_path_BC2,
                    epochs=epochs, debug_subset_size=None
                )

                if best_accuracy is None or val_accuracy > best_accuracy:
                    best_accuracy = val_accuracy
                    best_hp.update({
                        'augmentation': augmentation,
                        'loss_type': loss_type,
                        'factor': factor,
                        'val_loss': val_loss,
                        'val_accuracy': val_accuracy
                    })

print("Best hyperparameters for the model BioCLIP 2:")
print(best_hp)
# Out:
# Launching model with hyperparameters False, CE
# Using device: cuda
# BioCLIP 2!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-32-4019947473.py in <cell line: 0>()
#      22         if not augmentation:
#      23             print(f"Launching model with hyperparameters {augmentation}, {loss_type}")
# ---> 24             val_loss, val_accuracy = create_model_and_predict(
#      25                 folder_name="taxas", use_bioclip=True, augmentation=augmentation,
#      26                 augmentation_factor=None, loss_type=loss_type,
#
# /tmp/ipython-input-20-2304292675.py in create_model_and_predict(folder_name, use_bioclip, bioclip_version, augmentation, augmentation_factor, loss_type, output_dir, model_name, verbose, save_model, embeddings_save_path, epochs, debug_subset_size)
#      16
#      17     if use_bioclip:
# ---> 18         feature_extractor, preprocess = get_bioclip_embeddings_extractor_model(device, bioclip_version)
#      19         feature_extractor = feature_extractor.to(device)
#      20     else:
#
# /tmp/ipython-input-11-3858599571.py in get_bioclip_embeddings_extractor_model(device, bioclip_version)
#      18     if bioclip_version==2:
#      19         print("BioCLIP 2!")
# ---> 20         model, _, preprocess = open_clip.create_model_and_transforms('hf-hub:imageomics/bioclip-2')
#      21     else:
#      22         model, _, preprocess = open_clip.create_model_and_transforms('hf-hub:imageomics/bioclip')
#
# /usr/local/lib/python3.11/dist-packages/open_clip/factory.py in create_model_and_transforms(model_name, pretrained, precision, device, jit, force_quick_gelu, force_custom_text, force_patch_dropout, force_image_size, image_mean, image_std, image_interpolation, image_resize_mode, aug_cfg, pretrained_image, pretrained_hf, cache_dir, output_dict, load_weights_only, **model_kwargs)
#     500     )
#     501
# --> 502     model = create_model(
#     503         model_name,
#     504         pretrained,
#
# /usr/local/lib/python3.11/dist-packages/open_clip/factory.py in create_model(model_name, pretrained, precision, device, jit, force_quick_gelu, force_custom_text, force_patch_dropout, force_image_size, force_preprocess_cfg, pretrained_image, pretrained_hf, cache_dir, output_dict, require_pretrained, load_weights_only, **model_kwargs)
#     350             model = CustomTextCLIP(**model_cfg, cast_dtype=cast_dtype)
#     351     else:
# --> 352         model = CLIP(**model_cfg, cast_dtype=cast_dtype)
#     353
#     354     if precision in ("fp16", "bf16"):
#
# /usr/local/lib/python3.11/dist-packages/open_clip/model.py in __init__(self, embed_dim, vision_cfg, text_cfg, quick_gelu, init_logit_scale, init_logit_bias, nonscalar_logit_scale, cast_dtype, output_dict)
#     240         self.visual = _build_vision_tower(embed_dim, vision_cfg, quick_gelu, cast_dtype)
#     241
# --> 242         text = _build_text_tower(embed_dim, text_cfg, quick_gelu, cast_dtype)
#     243         self.transformer = text.transformer
#     244         self.context_length = text.context_length
#
# /usr/local/lib/python3.11/dist-packages/open_clip/model.py in _build_text_tower(embed_dim, text_cfg, quick_gelu, cast_dtype)
#     198             act_layer = partial(act_layer, **text_cfg.act_kwargs)
#     199
# --> 200         text = TextTransformer(
#     201             context_length=text_cfg.context_length,
#     202             vocab_size=text_cfg.vocab_size,
#
# /usr/local/lib/python3.11/dist-packages/open_clip/transformer.py in __init__(self, context_length, vocab_size, width, heads, layers, mlp_ratio, ls_init_value, output_dim, embed_cls, no_causal_mask, pad_id, pool_type, proj_type, proj_bias, act_layer, norm_layer, output_tokens)
#     890         self.pool_type = pool_type
#     891
# --> 892         self.token_embedding = nn.Embedding(vocab_size, width)
#     893         if embed_cls:
#     894             self.cls_emb = nn.Parameter(torch.empty(width))
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/sparse.py in __init__(self, num_embeddings, embedding_dim, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse, _weight, _freeze, device, dtype)
#     168                 requires_grad=not _freeze,
#     169             )
# --> 170             self.reset_parameters()
#     171         else:
#     172             assert list(_weight.shape) == [
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/sparse.py in reset_parameters(self)
#     179
#     180     def reset_parameters(self) -> None:
# --> 181         init.normal_(self.weight)
#     182         self._fill_padding_idx_with_zero()
#     183
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/init.py in normal_(tensor, mean, std, generator)
#     191             normal_, (tensor,), tensor=tensor, mean=mean, std=std, generator=generator
#     192         )
# --> 193     return _no_grad_normal_(tensor, mean, std, generator)
#     194
#     195
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/init.py in _no_grad_normal_(tensor, mean, std, generator)
#      20 def _no_grad_normal_(tensor, mean, std, generator=None):
#      21     with torch.no_grad():
# ---> 22         return tensor.normal_(mean, std, generator=generator)
#      23
#      24
#
# KeyboardInterrupt:

# %%
#USARE VALORI DI BESTHP COME PARAMETRI

final_HP_search = {'augmentation': True, 'loss_type': 'CE', 'factor': 2, 'val_loss': 0.35223526106626696, 'val_accuracy': 0.8417397244677217}

model_name_final = 'best_HP_10000_epochs'
epochs=10000

create_model_and_predict(folder_name="taxas", use_bioclip=True, augmentation=final_HP_search['augmentation'],
                                          augmentation_factor=final_HP_search['factor'], loss_type=final_HP_search['loss_type'],
                                         bioclip_version=2, output_dir="invasive_species", model_name=model_name_final,
                                           save_model=True, verbose=True, embeddings_save_path=embeddings_save_path_BC2,
                                             epochs=epochs, debug_subset_size=None)
# Out:
# Using device: cuda
# BioCLIP 2!
# Model obtained...
# Feature extractor obtained..
# ✅ Embeddings already exist, loading from file...
# Extracting embeddings: 100%|██████████| 29/29 [00:45<00:00,  1.57s/it]
# Augmenting train dataset...
# 🔢 Class distribution in train set: Counter({0: 24744, 2: 9665, 1: 1625})
# ⚖️ Class weights: tensor([0.0988, 0.1352, 0.1090])
#
# 🔁 Epoch 1/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 438.12it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 760.48it/s]
# 📉 Train Loss: 0.7074 | Accuracy: 0.6989
# 📈 Val Loss:   0.5419 | Accuracy: 0.7454
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.81      0.84      0.83      6212
# NN Non-Invasive       0.00      0.00      0.00       183
#     NN Invasive       0.57      0.55      0.56      2388
#
#        accuracy                           0.75      8783
#       macro avg       0.46      0.46      0.46      8783
#    weighted avg       0.73      0.75      0.74      8783
# 🔁 Epoch 2/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 507.34it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1087.31it/s]
# 📉 Train Loss: 0.5642 | Accuracy: 0.7369
# 📈 Val Loss:   0.4999 | Accuracy: 0.7658
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.82      0.86      0.84      6212
# NN Non-Invasive       0.27      0.05      0.09       183
#     NN Invasive       0.61      0.59      0.60      2388
#
#        accuracy                           0.77      8783
#       macro avg       0.57      0.50      0.51      8783
#    weighted avg       0.75      0.77      0.76      8783
# 🔁 Epoch 3/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 507.60it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1038.64it/s]
# 📉 Train Loss: 0.5227 | Accuracy: 0.7506
# 📈 Val Loss:   0.4744 | Accuracy: 0.7834
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.83      0.88      0.85      6212
# NN Non-Invasive       0.33      0.14      0.19       183
#     NN Invasive       0.66      0.58      0.62      2388
#
#        accuracy                           0.78      8783
#       macro avg       0.61      0.53      0.55      8783
#    weighted avg       0.77      0.78      0.78      8783
# 🔁 Epoch 4/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 502.82it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1124.49it/s]
# 📉 Train Loss: 0.5000 | Accuracy: 0.7634
# 📈 Val Loss:   0.4609 | Accuracy: 0.7854
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.84      0.86      0.85      6212
# NN Non-Invasive       0.35      0.27      0.30       183
#     NN Invasive       0.65      0.63      0.64      2388
#
#        accuracy                           0.79      8783
#       macro avg       0.61      0.59      0.60      8783
#    weighted avg       0.78      0.79      0.78      8783
# 🔁 Epoch 5/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 481.23it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 792.44it/s]
# 📉 Train Loss: 0.4847 | Accuracy: 0.7721
# 📈 Val Loss:   0.4499 | Accuracy: 0.7899
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.85      0.85      0.85      6212
# NN Non-Invasive       0.35      0.33      0.34       183
#     NN Invasive       0.66      0.66      0.66      2388
#
#        accuracy                           0.79      8783
#       macro avg       0.62      0.61      0.62      8783
#    weighted avg       0.79      0.79      0.79      8783
# 🔁 Epoch 6/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 415.63it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1075.00it/s]
# 📉 Train Loss: 0.4727 | Accuracy: 0.7793
# 📈 Val Loss:   0.4452 | Accuracy: 0.7896
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.88      0.82      0.85      6212
# NN Non-Invasive       0.34      0.39      0.37       183
#     NN Invasive       0.64      0.75      0.69      2388
#
#        accuracy                           0.79      8783
#       macro avg       0.62      0.65      0.63      8783
#    weighted avg       0.80      0.79      0.79      8783
# 🔁 Epoch 7/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 504.04it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1045.80it/s]
# 📉 Train Loss: 0.4628 | Accuracy: 0.7851
# 📈 Val Loss:   0.4302 | Accuracy: 0.8003
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.85      0.87      0.86      6212
# NN Non-Invasive       0.39      0.33      0.36       183
#     NN Invasive       0.68      0.65      0.67      2388
#
#        accuracy                           0.80      8783
#       macro avg       0.64      0.62      0.63      8783
#    weighted avg       0.80      0.80      0.80      8783
# 🔁 Epoch 8/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 508.21it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1134.03it/s]
# 📉 Train Loss: 0.4546 | Accuracy: 0.7906
# 📈 Val Loss:   0.4252 | Accuracy: 0.7996
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.87      0.84      0.86      6212
# NN Non-Invasive       0.37      0.40      0.38       183
#     NN Invasive       0.66      0.72      0.69      2388
#
#        accuracy                           0.80      8783
#       macro avg       0.64      0.65      0.64      8783
#    weighted avg       0.81      0.80      0.80      8783
# 🔁 Epoch 9/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 500.86it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1079.16it/s]
# 📉 Train Loss: 0.4474 | Accuracy: 0.7948
# 📈 Val Loss:   0.4173 | Accuracy: 0.8061
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.87      0.86      0.86      6212
# NN Non-Invasive       0.37      0.37      0.37       183
#     NN Invasive       0.68      0.71      0.69      2388
#
#        accuracy                           0.81      8783
#       macro avg       0.64      0.64      0.64      8783
#    weighted avg       0.81      0.81      0.81      8783
# 🔁 Epoch 10/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 443.65it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 744.23it/s]
# 📉 Train Loss: 0.4411 | Accuracy: 0.7964
# 📈 Val Loss:   0.4168 | Accuracy: 0.8064
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.88      0.85      0.86      6212
# NN Non-Invasive       0.39      0.52      0.44       183
#     NN Invasive       0.68      0.73      0.70      2388
#
#        accuracy                           0.81      8783
#       macro avg       0.65      0.70      0.67      8783
#    weighted avg       0.81      0.81      0.81      8783
# 🔁 Epoch 11/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 446.70it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1005.38it/s]
# 📉 Train Loss: 0.4351 | Accuracy: 0.8025
# 📈 Val Loss:   0.4107 | Accuracy: 0.8109
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.88      0.85      0.87      6212
# NN Non-Invasive       0.41      0.52      0.46       183
#     NN Invasive       0.68      0.73      0.70      2388
#
#        accuracy                           0.81      8783
#       macro avg       0.66      0.70      0.68      8783
#    weighted avg       0.82      0.81      0.81      8783
# 🔁 Epoch 12/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 498.09it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1117.66it/s]
# 📉 Train Loss: 0.4298 | Accuracy: 0.8043
# 📈 Val Loss:   0.4102 | Accuracy: 0.8161
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.84      0.92      0.88      6212
# NN Non-Invasive       0.44      0.42      0.43       183
#     NN Invasive       0.77      0.58      0.66      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.68      0.64      0.66      8783
#    weighted avg       0.81      0.82      0.81      8783
# 🔁 Epoch 13/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 495.19it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1063.67it/s]
# 📉 Train Loss: 0.4249 | Accuracy: 0.8068
# 📈 Val Loss:   0.4017 | Accuracy: 0.8153
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.88      0.86      0.87      6212
# NN Non-Invasive       0.42      0.51      0.46       183
#     NN Invasive       0.69      0.72      0.71      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.66      0.70      0.68      8783
#    weighted avg       0.82      0.82      0.82      8783
# 🔁 Epoch 14/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 495.26it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1016.31it/s]
# 📉 Train Loss: 0.4205 | Accuracy: 0.8088
# 📈 Val Loss:   0.3963 | Accuracy: 0.8183
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.86      0.89      0.88      6212
# NN Non-Invasive       0.43      0.40      0.41       183
#     NN Invasive       0.73      0.65      0.69      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.67      0.65      0.66      8783
#    weighted avg       0.81      0.82      0.82      8783
# 🔁 Epoch 15/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 402.80it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 716.45it/s]
# 📉 Train Loss: 0.4166 | Accuracy: 0.8111
# 📈 Val Loss:   0.3980 | Accuracy: 0.8169
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.87      0.87      0.87      6212
# NN Non-Invasive       0.41      0.56      0.47       183
#     NN Invasive       0.72      0.69      0.70      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.66      0.71      0.68      8783
#    weighted avg       0.82      0.82      0.82      8783
# 🔁 Epoch 16/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 489.40it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1059.70it/s]
# 📉 Train Loss: 0.4124 | Accuracy: 0.8131
# 📈 Val Loss:   0.3911 | Accuracy: 0.8212
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.88      0.87      0.87      6212
# NN Non-Invasive       0.45      0.49      0.47       183
#     NN Invasive       0.71      0.72      0.71      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.68      0.69      0.69      8783
#    weighted avg       0.82      0.82      0.82      8783
# 🔁 Epoch 17/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 496.25it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1066.41it/s]
# 📉 Train Loss: 0.4090 | Accuracy: 0.8151
# 📈 Val Loss:   0.3974 | Accuracy: 0.8158
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.84      0.87      6212
# NN Non-Invasive       0.40      0.63      0.49       183
#     NN Invasive       0.69      0.76      0.72      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.66      0.74      0.69      8783
#    weighted avg       0.83      0.82      0.82      8783
# 🔁 Epoch 18/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 496.37it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1029.94it/s]
# 📉 Train Loss: 0.4055 | Accuracy: 0.8166
# 📈 Val Loss:   0.3916 | Accuracy: 0.8207
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.88      0.86      0.87      6212
# NN Non-Invasive       0.41      0.61      0.49       183
#     NN Invasive       0.71      0.73      0.72      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.67      0.73      0.69      8783
#    weighted avg       0.83      0.82      0.82      8783
# 🔁 Epoch 19/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 474.13it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 766.44it/s]
# 📉 Train Loss: 0.4025 | Accuracy: 0.8180
# 📈 Val Loss:   0.3895 | Accuracy: 0.8206
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.85      0.87      6212
# NN Non-Invasive       0.42      0.63      0.51       183
#     NN Invasive       0.70      0.75      0.72      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.67      0.75      0.70      8783
#    weighted avg       0.83      0.82      0.82      8783
# 🔁 Epoch 20/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 415.46it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1070.59it/s]
# 📉 Train Loss: 0.3995 | Accuracy: 0.8191
# 📈 Val Loss:   0.3842 | Accuracy: 0.8260
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.88      0.87      0.88      6212
# NN Non-Invasive       0.44      0.56      0.49       183
#     NN Invasive       0.72      0.72      0.72      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.68      0.72      0.70      8783
#    weighted avg       0.83      0.83      0.83      8783
# 🔁 Epoch 21/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 492.78it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 932.35it/s]
# 📉 Train Loss: 0.3963 | Accuracy: 0.8217
# 📈 Val Loss:   0.3833 | Accuracy: 0.8243
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.88      0.87      0.88      6212
# NN Non-Invasive       0.43      0.60      0.50       183
#     NN Invasive       0.72      0.72      0.72      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.68      0.73      0.70      8783
#    weighted avg       0.83      0.82      0.83      8783
# 🔁 Epoch 22/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 493.36it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1023.33it/s]
# 📉 Train Loss: 0.3939 | Accuracy: 0.8223
# 📈 Val Loss:   0.3847 | Accuracy: 0.8236
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.86      0.88      6212
# NN Non-Invasive       0.42      0.65      0.51       183
#     NN Invasive       0.71      0.73      0.72      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.67      0.75      0.70      8783
#    weighted avg       0.83      0.82      0.83      8783
# 🔁 Epoch 23/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 493.10it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1041.60it/s]
# 📉 Train Loss: 0.3916 | Accuracy: 0.8236
# 📈 Val Loss:   0.3806 | Accuracy: 0.8261
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.86      0.88      6212
# NN Non-Invasive       0.44      0.61      0.51       183
#     NN Invasive       0.71      0.75      0.73      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.68      0.74      0.71      8783
#    weighted avg       0.83      0.83      0.83      8783
# 🔁 Epoch 24/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 413.30it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 740.23it/s]
# 📉 Train Loss: 0.3885 | Accuracy: 0.8248
# 📈 Val Loss:   0.3782 | Accuracy: 0.8290
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.87      0.90      0.88      6212
# NN Non-Invasive       0.47      0.51      0.49       183
#     NN Invasive       0.75      0.67      0.71      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.70      0.69      0.69      8783
#    weighted avg       0.83      0.83      0.83      8783
# 🔁 Epoch 25/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 460.06it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1056.97it/s]
# 📉 Train Loss: 0.3863 | Accuracy: 0.8255
# 📈 Val Loss:   0.3828 | Accuracy: 0.8204
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.84      0.87      6212
# NN Non-Invasive       0.42      0.65      0.51       183
#     NN Invasive       0.69      0.79      0.73      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.67      0.76      0.71      8783
#    weighted avg       0.83      0.82      0.83      8783
# 🔁 Epoch 26/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 486.56it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1022.73it/s]
# 📉 Train Loss: 0.3841 | Accuracy: 0.8266
# 📈 Val Loss:   0.3806 | Accuracy: 0.8278
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.86      0.88      6212
# NN Non-Invasive       0.42      0.68      0.52       183
#     NN Invasive       0.72      0.74      0.73      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.68      0.76      0.71      8783
#    weighted avg       0.84      0.83      0.83      8783
# 🔁 Epoch 27/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 481.72it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1009.39it/s]
# 📉 Train Loss: 0.3818 | Accuracy: 0.8272
# 📈 Val Loss:   0.3717 | Accuracy: 0.8307
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.87      0.88      6212
# NN Non-Invasive       0.49      0.58      0.53       183
#     NN Invasive       0.72      0.74      0.73      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.70      0.73      0.71      8783
#    weighted avg       0.83      0.83      0.83      8783
# 🔁 Epoch 28/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 465.01it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 747.48it/s]
# 📉 Train Loss: 0.3801 | Accuracy: 0.8298
# 📈 Val Loss:   0.3770 | Accuracy: 0.8285
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.87      0.88      6212
# NN Non-Invasive       0.43      0.65      0.52       183
#     NN Invasive       0.72      0.75      0.73      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.68      0.75      0.71      8783
#    weighted avg       0.84      0.83      0.83      8783
# 🔁 Epoch 29/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 399.60it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 984.53it/s]
# 📉 Train Loss: 0.3776 | Accuracy: 0.8303
# 📈 Val Loss:   0.3721 | Accuracy: 0.8317
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.88      0.88      0.88      6212
# NN Non-Invasive       0.45      0.62      0.53       183
#     NN Invasive       0.74      0.72      0.73      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.69      0.74      0.71      8783
#    weighted avg       0.83      0.83      0.83      8783
# 🔁 Epoch 30/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 488.26it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1033.74it/s]
# 📉 Train Loss: 0.3757 | Accuracy: 0.8312
# 📈 Val Loss:   0.3776 | Accuracy: 0.8247
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.84      0.87      6212
# NN Non-Invasive       0.43      0.69      0.53       183
#     NN Invasive       0.70      0.78      0.74      2388
#
#        accuracy                           0.82      8783
#       macro avg       0.68      0.77      0.71      8783
#    weighted avg       0.84      0.82      0.83      8783
# 🔁 Epoch 31/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 484.24it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1004.12it/s]
# 📉 Train Loss: 0.3741 | Accuracy: 0.8330
# 📈 Val Loss:   0.3686 | Accuracy: 0.8345
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.87      0.90      0.89      6212
# NN Non-Invasive       0.52      0.56      0.54       183
#     NN Invasive       0.76      0.67      0.71      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.71      0.71      0.71      8783
#    weighted avg       0.83      0.83      0.83      8783
# 🔁 Epoch 32/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 494.97it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 989.84it/s]
# 📉 Train Loss: 0.3725 | Accuracy: 0.8335
# 📈 Val Loss:   0.3681 | Accuracy: 0.8335
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.88      0.88      6212
# NN Non-Invasive       0.47      0.61      0.53       183
#     NN Invasive       0.73      0.74      0.73      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.70      0.74      0.72      8783
#    weighted avg       0.84      0.83      0.83      8783
# 🔁 Epoch 33/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 427.66it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 778.27it/s]
# 📉 Train Loss: 0.3709 | Accuracy: 0.8341
# 📈 Val Loss:   0.3671 | Accuracy: 0.8325
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.87      0.88      6212
# NN Non-Invasive       0.49      0.61      0.54       183
#     NN Invasive       0.71      0.76      0.74      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.70      0.75      0.72      8783
#    weighted avg       0.84      0.83      0.83      8783
# 🔁 Epoch 34/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 448.74it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 949.39it/s]
# 📉 Train Loss: 0.3685 | Accuracy: 0.8353
# 📈 Val Loss:   0.3750 | Accuracy: 0.8274
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.85      0.88      6212
# NN Non-Invasive       0.43      0.73      0.54       183
#     NN Invasive       0.70      0.78      0.74      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.68      0.79      0.72      8783
#    weighted avg       0.84      0.83      0.83      8783
# 🔁 Epoch 35/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 489.30it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1024.32it/s]
# 📉 Train Loss: 0.3669 | Accuracy: 0.8368
# 📈 Val Loss:   0.3698 | Accuracy: 0.8332
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.87      0.90      0.89      6212
# NN Non-Invasive       0.47      0.64      0.54       183
#     NN Invasive       0.77      0.67      0.71      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.70      0.74      0.71      8783
#    weighted avg       0.83      0.83      0.83      8783
# 🔁 Epoch 36/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 486.79it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1027.64it/s]
# 📉 Train Loss: 0.3647 | Accuracy: 0.8383
# 📈 Val Loss:   0.3729 | Accuracy: 0.8306
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.87      0.88      6212
# NN Non-Invasive       0.42      0.73      0.53       183
#     NN Invasive       0.73      0.74      0.74      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.68      0.78      0.72      8783
#    weighted avg       0.84      0.83      0.83      8783
# 🔁 Epoch 37/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 483.25it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 975.33it/s]
# 📉 Train Loss: 0.3637 | Accuracy: 0.8375
# 📈 Val Loss:   0.3705 | Accuracy: 0.8321
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.87      0.88      6212
# NN Non-Invasive       0.44      0.73      0.55       183
#     NN Invasive       0.72      0.75      0.74      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.69      0.78      0.72      8783
#    weighted avg       0.84      0.83      0.84      8783
# 🔁 Epoch 38/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 398.41it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 699.89it/s]
# 📉 Train Loss: 0.3623 | Accuracy: 0.8374
# 📈 Val Loss:   0.3660 | Accuracy: 0.8354
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.88      0.88      6212
# NN Non-Invasive       0.47      0.70      0.56       183
#     NN Invasive       0.74      0.72      0.73      2388
#
#        accuracy                           0.84      8783
#       macro avg       0.70      0.77      0.73      8783
#    weighted avg       0.84      0.84      0.84      8783
# 🔁 Epoch 39/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 487.71it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 969.52it/s]
# 📉 Train Loss: 0.3605 | Accuracy: 0.8386
# 📈 Val Loss:   0.3598 | Accuracy: 0.8378
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.87      0.90      0.89      6212
# NN Non-Invasive       0.58      0.53      0.55       183
#     NN Invasive       0.75      0.69      0.72      2388
#
#        accuracy                           0.84      8783
#       macro avg       0.73      0.71      0.72      8783
#    weighted avg       0.83      0.84      0.84      8783
# 🔁 Epoch 40/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 483.31it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 983.86it/s]
# 📉 Train Loss: 0.3590 | Accuracy: 0.8393
# 📈 Val Loss:   0.3655 | Accuracy: 0.8315
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.91      0.85      0.88      6212
# NN Non-Invasive       0.51      0.63      0.56       183
#     NN Invasive       0.70      0.80      0.74      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.70      0.76      0.73      8783
#    weighted avg       0.84      0.83      0.83      8783
# 🔁 Epoch 41/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 483.23it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 993.04it/s]
# 📉 Train Loss: 0.3579 | Accuracy: 0.8400
# 📈 Val Loss:   0.3628 | Accuracy: 0.8363
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.88      0.88      6212
# NN Non-Invasive       0.49      0.68      0.57       183
#     NN Invasive       0.74      0.73      0.73      2388
#
#        accuracy                           0.84      8783
#       macro avg       0.70      0.76      0.73      8783
#    weighted avg       0.84      0.84      0.84      8783
# 🔁 Epoch 42/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 442.44it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 703.42it/s]
# 📉 Train Loss: 0.3564 | Accuracy: 0.8414
# 📈 Val Loss:   0.3670 | Accuracy: 0.8326
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.87      0.88      6212
# NN Non-Invasive       0.44      0.73      0.55       183
#     NN Invasive       0.73      0.75      0.74      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.69      0.78      0.72      8783
#    weighted avg       0.84      0.83      0.84      8783
# 🔁 Epoch 43/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 410.24it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1013.48it/s]
# 📉 Train Loss: 0.3543 | Accuracy: 0.8431
# 📈 Val Loss:   0.3653 | Accuracy: 0.8371
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.87      0.88      6212
# NN Non-Invasive       0.47      0.75      0.58       183
#     NN Invasive       0.74      0.75      0.74      2388
#
#        accuracy                           0.84      8783
#       macro avg       0.70      0.79      0.73      8783
#    weighted avg       0.84      0.84      0.84      8783
# 🔁 Epoch 44/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 479.20it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 981.58it/s]
# 📉 Train Loss: 0.3533 | Accuracy: 0.8438
# 📈 Val Loss:   0.3628 | Accuracy: 0.8381
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.87      0.88      6212
# NN Non-Invasive       0.49      0.73      0.59       183
#     NN Invasive       0.73      0.76      0.74      2388
#
#        accuracy                           0.84      8783
#       macro avg       0.71      0.79      0.74      8783
#    weighted avg       0.84      0.84      0.84      8783
# 🔁 Epoch 45/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 481.98it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 932.36it/s]
# 📉 Train Loss: 0.3523 | Accuracy: 0.8433
# 📈 Val Loss:   0.3573 | Accuracy: 0.8395
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.88      0.90      0.89      6212
# NN Non-Invasive       0.55      0.61      0.58       183
#     NN Invasive       0.75      0.70      0.73      2388
#
#        accuracy                           0.84      8783
#       macro avg       0.73      0.74      0.73      8783
#    weighted avg       0.84      0.84      0.84      8783
# 🔁 Epoch 46/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 489.51it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 1004.14it/s]
# 📉 Train Loss: 0.3505 | Accuracy: 0.8445
# 📈 Val Loss:   0.3600 | Accuracy: 0.8371
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.87      0.88      6212
# NN Non-Invasive       0.52      0.69      0.59       183
#     NN Invasive       0.72      0.76      0.74      2388
#
#        accuracy                           0.84      8783
#       macro avg       0.71      0.77      0.74      8783
#    weighted avg       0.84      0.84      0.84      8783
# 🔁 Epoch 47/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 396.62it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 732.52it/s]
# 📉 Train Loss: 0.3493 | Accuracy: 0.8438
# 📈 Val Loss:   0.3688 | Accuracy: 0.8318
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.86      0.88      6212
# NN Non-Invasive       0.42      0.78      0.55       183
#     NN Invasive       0.73      0.76      0.74      2388
#
#        accuracy                           0.83      8783
#       macro avg       0.68      0.80      0.72      8783
#    weighted avg       0.84      0.83      0.84      8783
# 🔁 Epoch 48/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 446.99it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 978.25it/s]
# 📉 Train Loss: 0.3479 | Accuracy: 0.8458
# 📈 Val Loss:   0.3608 | Accuracy: 0.8364
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.87      0.88      6212
# NN Non-Invasive       0.50      0.73      0.59       183
#     NN Invasive       0.72      0.76      0.74      2388
#
#        accuracy                           0.84      8783
#       macro avg       0.71      0.79      0.74      8783
#    weighted avg       0.84      0.84      0.84      8783
# 🔁 Epoch 49/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 480.31it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 994.99it/s]
# 📉 Train Loss: 0.3471 | Accuracy: 0.8449
# 📈 Val Loss:   0.3575 | Accuracy: 0.8396
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.89      0.88      0.89      6212
# NN Non-Invasive       0.53      0.68      0.60       183
#     NN Invasive       0.74      0.74      0.74      2388
#
#        accuracy                           0.84      8783
#       macro avg       0.72      0.77      0.74      8783
#    weighted avg       0.84      0.84      0.84      8783
# 🔁 Epoch 50/50
# Training: 100%|██████████| 1127/1127 [00:02<00:00, 481.20it/s]
# Evaluating: 100%|██████████| 275/275 [00:00<00:00, 947.00it/s]
# 📉 Train Loss: 0.3459 | Accuracy: 0.8453
# 📈 Val Loss:   0.3595 | Accuracy: 0.8382
#
# 📋 Classification Report:
#                  precision    recall  f1-score   support
#
#          Native       0.90      0.87      0.89      6212
# NN Non-Invasive       0.49      0.74      0.59       183
#     NN Invasive       0.73      0.76      0.74      2388
#
#        accuracy                           0.84      8783
#       macro avg       0.71      0.79      0.74      8783
#    weighted avg       0.84      0.84      0.84      8783
# 📝 Appended log to /content/drive/MyDrive/Thesis/invasive_species/logs/training_log.json
# Full model built...
# Total execution time: 297.05 seconds
# (0.3594989493144857, 0.838210178754412)
