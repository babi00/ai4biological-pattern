# %% [markdown]
# Given the list of original regions and mapped regions, we now take each coordinate in the metadata of the picture and map it to one of the original regions, if possible, otherwise we map it to the country obtained from the coordinates.

# %%
import os
import pandas as pd

# %%
#this path contains the csv files with the coordinates for each picture of each species
#(lythrum_acutangulum_metadata.csv, lythrum_alatum_metadata.csv, lythrum_album_metadata.csv, ...)
metadata_path = './support_files/taxas/taxas/metadata/'

# %%
def coordinate

# %%
for name in os.listdir(metadata_path)[:1]:
    print(name)
    df = pd.read_csv(metadata_path+name)
    print(df)
# Out:
# lythrum_acutangulum_metadata.csv
#                         filename  \
# 0    lythrum_acutangulum_001.jpg
# 1   lythrum_acutangulum_002.jpeg
# 2   lythrum_acutangulum_003.jpeg
# 3   lythrum_acutangulum_004.jpeg
# 4   lythrum_acutangulum_005.jpeg
# 5   lythrum_acutangulum_006.jpeg
# 6   lythrum_acutangulum_007.jpeg
# 7   lythrum_acutangulum_008.jpeg
# 8   lythrum_acutangulum_009.jpeg
# 9   lythrum_acutangulum_010.jpeg
# 10  lythrum_acutangulum_011.jpeg
# 11  lythrum_acutangulum_012.jpeg
# 12  lythrum_acutangulum_013.jpeg
# 13  lythrum_acutangulum_014.jpeg
# 14  lythrum_acutangulum_015.jpeg
# 15  lythrum_acutangulum_016.jpeg
# 16  lythrum_acutangulum_017.jpeg
# 17  lythrum_acutangulum_018.jpeg
# 18  lythrum_acutangulum_019.jpeg
# 19  lythrum_acutangulum_020.jpeg
# 20  lythrum_acutangulum_021.jpeg
# 21  lythrum_acutangulum_022.jpeg
# 22  lythrum_acutangulum_023.jpeg
# 23  lythrum_acutangulum_024.jpeg
#
#                                                   url license_code  \
# ...
