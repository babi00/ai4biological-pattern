# %% [markdown]
# Given the list of original regions, we asked ChatGPT (GPT-4o) to extract for each of them the Nominatim API query to extract the point coordinates and the bounding box coordinates.
#
# In this file we execute the API calls to obtain the coordinates for each region. If for some region the API call fails, we inspect these cases manually.
#
#
# CASI STRANI IDENTIFICATI:
#
# Central Chile ritorna una stazione di servizio che sta all'estremo nord del Chile.

# %%
import pandas as pd
import requests
import time
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
COMPLETE_REGION_DATASET_PATH = './support_files/Complete_Region_Dataset.csv' #obtained with GPT-4o
COMPLETE_REGION_DATASET_UPDATED_PATH = './support_files/Updated_Complete_Region_Dataset.csv' #save the updated dataframe generated by us

# %%
def obtain_coordinates(url: str) -> tuple[float, float, list, float]:
    """For each region, from the url of the API call to OpenStreetMap obtain the point coordinates and the bounding box coordinates"""

    # url = "https://nominatim.openstreetmap.org/search?country=Yemen&format=json&limit=1"

    # Send the GET request
    response = requests.get(url, headers={'User-Agent': 's319848@studenti.polito.it'})

    # Handle the response
    if response.status_code == 200:
        data = response.json()

        if data != []:
            lat = float(data[0]['lat']) #point coordinate for latitude of the region
            lon = float(data[0]['lon']) #point coordinate for longitude of the region
            bbox_str = data[0]['boundingbox'] #bounding box for the region (originally list of strings)
            bbox = [float(x) for x in bbox_str]
            area = abs(bbox[1] - bbox[0]) * abs(bbox[3] - bbox[2])

        else:
            print(f"Region not found for url = {url}")
            return (None, None, None, None)

        return (lat, lon, bbox, area)
    else:
        print(f"url: {url} \nError:", response.status_code)
        return (None, None, None, None)

# %%
def fill_dataset(regions_path: str) -> pd.DataFrame:
    """Take the incomplete dataset and fill it with the coordinates by calling the API with the correct url"""

    regions_df = pd.read_csv(regions_path)

    for i, row in regions_df.iterrows():

        url = row['Nominatim URL']

        (lat, lon, bbox, area) = obtain_coordinates(url)

        regions_df.at[i, 'lat'] = lat
        regions_df.at[i, 'lon'] = lon
        regions_df.at[i, 'bbox'] = ''
        regions_df.at[i, 'bbox'] = bbox
        regions_df.at[i, 'area'] = area

        time.sleep(1)

    return regions_df

    #obtain the tuple (lat, lon, bbox) with the function obtain_coordinates, plug it in the dataset. Manually identify absent cases

# %%
regions_df_complete = fill_dataset(COMPLETE_REGION_DATASET_PATH)
regions_df_complete.to_csv(COMPLETE_REGION_DATASET_UPDATED_PATH, index=False)
regions_df_complete
# Out:
# Region not found for url = https://nominatim.openstreetmap.org/search?q=Northeastern%20Argentina&format=json&limit=1
# Region not found for url = https://nominatim.openstreetmap.org/search?q=Northwestern%20Argentina&format=json&limit=1
# Region not found for url = https://nominatim.openstreetmap.org/search?q=Southern%20Argentina&format=json&limit=1
# Region not found for url = https://nominatim.openstreetmap.org/search?q=Cape+Provinces+South+Africa&format=json&limit=1
# Region not found for url = https://nominatim.openstreetmap.org/search?q=Central+European+Russia&format=json&limit=1
# Region not found for url = https://nominatim.openstreetmap.org/search?q=Northern+Chile&format=json&limit=1
# Region not found for url = https://nominatim.openstreetmap.org/search?q=North-Central+China&format=json&limit=1
# Region not found for url = https://nominatim.openstreetmap.org/search?q=Czech+Republic+and+Slovakia&format=json&limit=1
# ...

# %%
georgia_coordinates = obtain_coordinates("https://nominatim.openstreetmap.org/search?country=USA&state=Georgia&format=json&limit=1")

print(type(georgia_coordinates[0]))
print(georgia_coordinates)
# Out:
# <class 'float'>
# (32.3293809, -83.1137366, [30.3556558, 35.0006769, -85.605165, -80.751429], 22.545706133829594)

# %% [markdown]
# After completing the dataset with the bounding boxes, we check for which of the regions OSM got it wrong, identifying a point location instead of a region. First we compute the distribution of the areas.

# %%
regions_df_complete = pd.read_csv(COMPLETE_REGION_DATASET_UPDATED_PATH)

areas_list = regions_df_complete['area'].to_list()
clean_list = [x for x in areas_list if not math.isnan(x)]

# plt.hist(clean_list, bins=190)
percentile_5 = np.percentile(clean_list, q=5, method='nearest')
percentile_10 = np.percentile(clean_list, q=10, method='nearest')
percentile_15 = np.percentile(clean_list, q=15, method='nearest')
percentile_20 = np.percentile(clean_list, q=20, method='nearest')

print(f"Total number of clean areas: {len(clean_list)}")

print(f"Number of elements under the 5th percentile ({percentile_5}) : {len([x for x in clean_list if x<percentile_5])}")
print(f"Region corresponding to 5th percentile: {regions_df_complete[regions_df_complete['area']==percentile_5]['Original name']}\n")

print(f"Number of elements under the 10th percentile ({percentile_10}) : {len([x for x in clean_list if x<percentile_10])}")
print(f"Region corresponding to 10th percentile: {regions_df_complete[regions_df_complete['area']==percentile_10]['Original name']}\n")
#10th percentile is Norfolk Islands, which is an actual region
#We look around (up and down) Norfolk Islands to see when actually regions become points.
# Out:
# Total number of clean areas: 180
# Number of elements under the 5th percentile (6.259318299995982e-06) : 9
# Region corresponding to 5th percentile: 33    China South-Central
# Name: Original name, dtype: object
#
# Number of elements under the 10th percentile (0.293685889621084) : 18
# Region corresponding to 10th percentile: 121    Norfolk Is.
# Name: Original name, dtype: object

# %%
regions_df_complete.sort_values(by='area', ascending=True)
# Out:
#                  Original name                   Entire name  \
# 20                Brazil South     Southern Region of Brazil
# 187              West Himalaya              Western Himalaya
# 97                 Mexico Gulf         Gulf Region of Mexico
# 86               Lebanon-Syria             Lebanon and Syria
# 188               West Siberia      Western Siberia (Russia)
# ..                         ...                           ...
# 125      North European Russia      Northern European Russia
# 127  Northwest European Russia  Northwestern European Russia
# 135                  Palestine            State of Palestine
# 160      South European Russia      Southern European Russia
# 171              Transcaucasus                 Transcaucasia
#
#                                    OSM Tags  \
# 20                             place=region
# 187                            place=region
# 97                             place=region
# 86                             place=region
# ...

# %% [markdown]
# By manually inspecting the dataframe, sorting area by ascending values, we can see that the first region with a small area but which is a correct region is the region of District of Columbia (index = 45).
# Everything below that value (16 regions) is a wrong region, as can be seen by looking at which regions report these values.
